# %%
# !pip install matchms
# !pip install rdkit
# !pip install torch_geometric
# !pip install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting matchms
#   Downloading matchms-0.18.0-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.6/109.6 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from matchms) (3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from matchms) (1.22.4)
# Collecting pickydict>=0.4.0
#   Downloading pickydict-0.4.0-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from matchms) (3.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from matchms) (2.27.1)
# Collecting pyteomics>=4.2
#   Downloading pyteomics-4.6-py2.py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.1/235.1 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from matchms) (1.10.1)
# Collecting sparsestack>=0.4.1
#   Downloading sparsestack-0.4.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from matchms) (4.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from matchms) (4.65.0)
# Collecting deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: numba>=0.47 in /usr/local/lib/python3.10/dist-packages (from matchms) (0.56.4)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.47->matchms) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.47->matchms) (67.7.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->matchms) (1.14.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matchms) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matchms) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matchms) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matchms) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matchms) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matchms) (23.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matchms) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matchms) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->matchms) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->matchms) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->matchms) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->matchms) (2.0.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->matchms) (1.16.0)
# Installing collected packages: pyteomics, pickydict, deprecated, sparsestack, matchms
# Successfully installed deprecated-1.2.13 matchms-0.18.0 pickydict-0.4.0 pyteomics-4.6 sparsestack-0.4.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rdkit
#   Downloading rdkit-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 50.4 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (8.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.22.4)
# Installing collected packages: rdkit
# Successfully installed rdkit-2022.9.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch_geometric
#   Downloading torch_geometric-2.3.1.tar.gz (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.6/661.6 kB 24.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.22.4)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.0.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (4.65.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.10.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch_geometric) (2.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (3.1.0)
# Building wheels for collected packages: torch_geometric
#   Building wheel for torch_geometric (pyproject.toml) ... done
#   Created wheel for torch_geometric: filename=torch_geometric-2.3.1-py3-none-any.whl size=910476 sha256=928287bcb8ae88a850595f695b3909083534e6239d9cb6dba8fa67bdc5229df5
#   Stored in directory: /root/.cache/pip/wheels/ac/dc/30/e2874821ff308ee67dcd7a66dbde912411e19e35a1addda028
# Successfully built torch_geometric
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.3.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pickle5
#   Downloading pickle5-0.0.11.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 14.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pickle5
#   Building wheel for pickle5 (setup.py) ... done
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp310-cp310-linux_x86_64.whl size=256413 sha256=15fecb87e2bc3a140d27eed069a1308c7742d6efa4d36f0b51f43b8296a7b979
#   Stored in directory: /root/.cache/pip/wheels/7d/14/ef/4aab19d27fa8e58772be5c71c16add0426acf9e1f64353235c
# Successfully built pickle5
# Installing collected packages: pickle5
# Successfully installed pickle5-0.0.11

# %%
from matchms.importing import load_from_msp
import numpy as np
import os
import random
import pickle
from rdkit import Chem
from rdkit.Chem import Descriptors
import matchms
from matchms import Spectrum

import matplotlib.pyplot as plt
import warnings

from rdkit.Chem.rdmolops import GetAdjacencyMatrix

# Pytorch and Pytorch Geometric
import torch
from torch_geometric.data import Data
from torch.utils.data import DataLoader

import torch
from torch.nn import Linear
import torch.nn.functional as F 
from torch_geometric.nn import GCNConv, TopKPooling, global_mean_pool, GATConv
from torch_geometric.nn import global_mean_pool as gap, global_max_pool as gmp
import torch.nn as nn
from torch_geometric.data import DataLoader
from torch.optim.lr_scheduler import StepLR

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir("/content/drive/MyDrive/NIST_SMALL")
BASE_DIRECTORY = "/content/drive/MyDrive/NIST_SMALL"

TEST_DATA_SIZE = 5000
OUTPUT_SIZE = 1000
INTENSITY_POWER = 0.5

# %%
with open("/content/drive/MyDrive/NIST_SMALL/Preprocessed_test_pow_preparation_no_sparse_small.output", 'rb') as handle:
    data_list_test  = pickle.load(handle)

# %%
NUMBER_OF_VALIDATION = 5000
test_dataset = data_list_test[:NUMBER_OF_VALIDATION]

# %%
with open("/content/drive/MyDrive/NIST_SMALL/train_subset_pow.pkl", 'rb') as handle:
    train_dataset  = pickle.load(handle)

with open("/content/drive/MyDrive/NIST_SMALL/validation_subset_pow.pkl", 'rb') as handle:
    validation_dataset  = pickle.load(handle)

# %%
EMBEDDING_SIZE = 2000
NODE_FEATURES = 50
MASS_SHIFT = 5 
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def mask_prediction_by_mass(total_mass, raw_prediction, index_shift):
    # Zero out predictions to the right of the maximum possible mass.
    # input 
    # anchor_indices: shape (,batch_size) = ex [3,4,5]
    #     total_mass = Weights of whole molecule, not only fragment
    # data: shape (batch_size, embedding), embedding from GNN in our case
    # index_shift: int constant how far can heaviest fragment differ from weight of original molecule
    # 

    data = raw_prediction.type(torch.float64)
    
    total_mass = torch.round(total_mass).type(torch.int64)
    indices = torch.arange(data.shape[-1])[None, ...].to(device)

    right_of_total_mass = indices > (
            total_mass[..., None] +
            index_shift)
    return torch.where(right_of_total_mass, torch.zeros_like(data),
                        data)

# %%
def scatter_by_anchor_indices(anchor_indices, data, index_shift):
    # reverse vector by anchor_indices and rest set to zero
    # input 
    # anchor_indices: shape (,batch_size) = ex [3,4,5]
    #     total_mass = Weights of whole molecule, not only fragment
    # data: shape (batch_size, embedding), embedding from GNN in our case
    # index_shift: int constant how far can heaviest fragment differ from weight of original molecule
    
    index_shift = index_shift
    anchor_indices = anchor_indices
    data = data.type(torch.float64)
    batch_size = data.shape[0]
    
    num_data_columns = data.shape[-1]
    indices = torch.arange(num_data_columns)[None, ...].to(device)
    shifted_indices = anchor_indices[..., None] - indices + index_shift
    valid_indices = shifted_indices >= 0

   

    batch_indices = torch.tile(
          torch.arange(batch_size)[..., None], [1, num_data_columns]).to(device)
    shifted_indices += batch_indices * num_data_columns

    shifted_indices = torch.reshape(shifted_indices, [-1])
    num_elements = data.shape[0] * data.shape[1]
    row_indices = torch.arange(num_elements).to(device)
    stacked_indices = torch.stack([row_indices, shifted_indices], axis=1)


    lower_batch_boundaries = torch.reshape(batch_indices * num_data_columns, [-1])
    upper_batch_boundaries = torch.reshape(((batch_indices + 1) * num_data_columns),
                                          [-1])

    valid_indices = torch.logical_and(shifted_indices >= lower_batch_boundaries,
                                     shifted_indices < upper_batch_boundaries)

    stacked_indices = stacked_indices[valid_indices]

    dense_shape = torch.tile(torch.tensor(num_elements)[..., None], [2]).type(torch.int32)

    scattering_matrix = torch.sparse.FloatTensor(stacked_indices.type(torch.int64).T,
                                                 torch.ones_like(stacked_indices[:, 0]).type(torch.float64),
                                                dense_shape.tolist())

    flattened_data = torch.reshape(data, [-1])[..., None]
    flattened_output = torch.sparse.mm(scattering_matrix, flattened_data)
    return torch.reshape(torch.transpose(flattened_output, 0, 1), [-1, num_data_columns])

# %%
def reverse_prediction(total_mass, raw_prediction, index_shift):
    # reverse vector by anchor_indices and rest set to zero and make preproessing
    # input 
    # total_mass: shape (,batch_size) = ex [3,4,5]
    #     total_mass = Weights of whole molecule, not only fragment
    # raw_prediction: shape (batch_size, embedding), embedding from GNN in our case
    # index_shift: int constant how far can heaviest fragment differ from weight of original molecule
    #     total_mass = feature_dict[fmap_constants.MOLECULE_WEIGHT][..., 0]
    
    total_mass = torch.round(total_mass).type(torch.int32)
    return scatter_by_anchor_indices(
        total_mass, raw_prediction, index_shift)

# %%
def dot_product(true, pred, mass_pow=3, intensity_pow=0.6):
    # shape for true and pred is one dimensional array
    # pred (number_of_predicted_bins)
    # defaul value for mass_pow and intensity_pow is set for Stein dot product
    assert true.ndim == pred.ndim and true.ndim == 1
    length = true.shape[-1]
    mass = np.arange(length).astype(np.float64)
        
    wl = mass ** mass_pow * pred**intensity_pow
    wu = mass ** mass_pow * true**intensity_pow
    
    pred_weighted_norm = np.sqrt(np.sum((wl**2)))
    true_weighted_norm = np.sqrt(np.sum((wu**2)))
    
    result = np.sum(wl*wu) / (pred_weighted_norm * true_weighted_norm)
    
    return result

# %%
def validate_similarities(true, pred, mass_pow, intensity_pow):
    # Helper function for validation
    similarities = np.array([])
    for true_instance, pred_instance in zip(true, pred):
        tmp = dot_product(true_instance, pred_instance, mass_pow=mass_pow, intensity_pow=intensity_pow)
        
        similarities = np.concatenate((similarities, tmp), axis=None)
    return similarities

# %%
class SKIPblock(nn.Module):
    def __init__(self, in_features, hidden_features, bottleneck_factor=0.5, USE_dropout=True, dropout_rate = 0.2):
        super().__init__()
        #only need to change shape of the residual if num_channels changes (i.e. in_c != out_c)
        #[bs,in_c,seq_length]->conv(1,in_c,out_c)->[bs,out_c,seq_length]
        
        self.batchNorm1 = nn.BatchNorm1d(in_features)
        self.relu1 = nn.ReLU()
        if USE_dropout:
            self.dropout1 = nn.Dropout(dropout_rate)
        self.hidden1= nn.utils.weight_norm(nn.Linear(in_features, int(hidden_features * bottleneck_factor)),name='weight',dim=0)
        
        self.batchNorm2 = nn.BatchNorm1d(int(hidden_features * bottleneck_factor))
        self.relu2 = nn.ReLU()
        if USE_dropout:
            self.dropout2 = nn.Dropout(dropout_rate)
        self.hidden2 = nn.utils.weight_norm(nn.Linear(int(hidden_features * bottleneck_factor), in_features),name='weight',dim=0)

    def forward(self, x):
        
        hidden = self.batchNorm1(x)
        hidden = self.relu1(hidden)
        hidden = self.dropout1(hidden)
        hidden = self.hidden1(hidden)

        hidden = self.batchNorm2(hidden)
        hidden = self.relu2(hidden)
        hidden = self.dropout2(hidden)
        hidden = self.hidden2(hidden)

        hidden = hidden + x

        return hidden

# %%
class CONV_BIG(torch.nn.Module):
    def __init__(self):
        # Init parent
        super(CONV_BIG, self).__init__()
        torch.manual_seed(42)

        EMBEDDING_SIZE_REDUCED = int(EMBEDDING_SIZE*0.15)

        # GCN layers
        self.initial_conv = GCNConv(NODE_FEATURES, EMBEDDING_SIZE_REDUCED)
        self.conv1 = GCNConv(EMBEDDING_SIZE_REDUCED, EMBEDDING_SIZE_REDUCED)
        self.reluconv1 = nn.ReLU()
        self.conv2 = GCNConv(EMBEDDING_SIZE_REDUCED, EMBEDDING_SIZE_REDUCED)
        self.reluconv2 = nn.ReLU()
        self.conv3 = GCNConv(EMBEDDING_SIZE_REDUCED, EMBEDDING_SIZE_REDUCED)
        self.reluconv3 = nn.ReLU()
        self.conv4 = GCNConv(EMBEDDING_SIZE_REDUCED, EMBEDDING_SIZE_REDUCED)
        self.reluconv4 = nn.ReLU()
    
        self.bottleneck = Linear(EMBEDDING_SIZE_REDUCED, EMBEDDING_SIZE)

        self.skip1 = SKIPblock(EMBEDDING_SIZE, EMBEDDING_SIZE)
        self.skip2 = SKIPblock(EMBEDDING_SIZE, EMBEDDING_SIZE)
        self.skip3 = SKIPblock(EMBEDDING_SIZE, EMBEDDING_SIZE)
        self.skip4 = SKIPblock(EMBEDDING_SIZE, EMBEDDING_SIZE)
        self.skip5 = SKIPblock(EMBEDDING_SIZE, EMBEDDING_SIZE)
        self.skip6 = SKIPblock(EMBEDDING_SIZE, EMBEDDING_SIZE)
        self.skip7 = SKIPblock(EMBEDDING_SIZE, EMBEDDING_SIZE)
        self.relu_out_resnet = nn.ReLU()

        self.forward_prediction = Linear(EMBEDDING_SIZE, OUTPUT_SIZE)
        self.backward_prediction = Linear(EMBEDDING_SIZE, OUTPUT_SIZE)
        self.gate = Linear(EMBEDDING_SIZE, OUTPUT_SIZE)

        self.relu_out = nn.ReLU()

    def forward(self, x, edge_index, edge_weight, total_mass, batch_index):
        
        hidden = self.initial_conv(x, edge_index)
        hidden = F.relu(hidden)
        
        # Other Conv layers
        hidden = self.conv1(hidden, edge_index)
        hidden = self.reluconv1(hidden)
        hidden = self.conv2(hidden, edge_index)
        hidden = self.reluconv2(hidden)
        hidden = self.conv3(hidden, edge_index)
        hidden = self.reluconv3(hidden)
        hidden = self.conv4(hidden, edge_index)
        hidden = self.reluconv4(hidden)
     
        
        hidden = gap(hidden, batch_index)
        hidden = self.bottleneck(hidden)

        hidden = self.skip1(hidden)
        hidden = self.skip2(hidden)
        hidden = self.skip3(hidden)
        hidden = self.skip4(hidden)
        hidden = self.skip5(hidden)
        hidden = self.skip6(hidden)
        hidden = self.skip7(hidden)
        
        hidden = self.relu_out_resnet(hidden)

        # Bidirectional layer
        # Forward prediction
        forward_prediction_hidden = self.forward_prediction(hidden)
        forward_prediction_hidden = mask_prediction_by_mass(total_mass, forward_prediction_hidden, MASS_SHIFT)
        
        # # Backward prediction
        backward_prediction_hidden = self.backward_prediction(hidden)
        backward_prediction_hidden = reverse_prediction(total_mass, backward_prediction_hidden, MASS_SHIFT)
        
        # # Gate
        gate_hidden = self.gate(hidden)
        gate_hidden = F.sigmoid(gate_hidden)

        # # Apply a final (linear) classifier.
        out = gate_hidden * forward_prediction_hidden + (1. - gate_hidden) * backward_prediction_hidden
        out = self.relu_out(out)
        
        out = out.type(torch.float64)
        return out

model = CONV_BIG()
MODEL_NAME = "CONV_BIG_POW"
MODEL_SAVE = os.path.join(BASE_DIRECTORY, MODEL_NAME)
os.makedirs(MODEL_SAVE, mode=0o777, exist_ok=True)
print(model)
print("Number of parameters: ", sum(p.numel() for p in model.parameters()))
# Out:
# CONV_BIG(
#   (initial_conv): GCNConv(50, 300)
#   (conv1): GCNConv(300, 300)
#   (reluconv1): ReLU()
#   (conv2): GCNConv(300, 300)
#   (reluconv2): ReLU()
#   (conv3): GCNConv(300, 300)
#   (reluconv3): ReLU()
#   (conv4): GCNConv(300, 300)
#   (reluconv4): ReLU()
#   (bottleneck): Linear(in_features=300, out_features=2000, bias=True)
#   (skip1): SKIPblock(
#     (batchNorm1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (hidden1): Linear(in_features=2000, out_features=1000, bias=True)
#     (batchNorm2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (hidden2): Linear(in_features=1000, out_features=2000, bias=True)
#   )
#   (skip2): SKIPblock(
#     (batchNorm1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (hidden1): Linear(in_features=2000, out_features=1000, bias=True)
#     (batchNorm2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (hidden2): Linear(in_features=1000, out_features=2000, bias=True)
#   )
#   (skip3): SKIPblock(
#     (batchNorm1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (hidden1): Linear(in_features=2000, out_features=1000, bias=True)
#     (batchNorm2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (hidden2): Linear(in_features=1000, out_features=2000, bias=True)
#   )
#   (skip4): SKIPblock(
#     (batchNorm1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (hidden1): Linear(in_features=2000, out_features=1000, bias=True)
#     (batchNorm2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (hidden2): Linear(in_features=1000, out_features=2000, bias=True)
#   )
#   (skip5): SKIPblock(
#     (batchNorm1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (hidden1): Linear(in_features=2000, out_features=1000, bias=True)
#     (batchNorm2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (hidden2): Linear(in_features=1000, out_features=2000, bias=True)
#   )
#   (skip6): SKIPblock(
#     (batchNorm1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (hidden1): Linear(in_features=2000, out_features=1000, bias=True)
#     (batchNorm2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (hidden2): Linear(in_features=1000, out_features=2000, bias=True)
#   )
#   (skip7): SKIPblock(
#     (batchNorm1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (hidden1): Linear(in_features=2000, out_features=1000, bias=True)
#     (batchNorm2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (hidden2): Linear(in_features=1000, out_features=2000, bias=True)
#   )
#   (relu_out_resnet): ReLU()
#   (forward_prediction): Linear(in_features=2000, out_features=1000, bias=True)
#   (backward_prediction): Linear(in_features=2000, out_features=1000, bias=True)
#   (gate): Linear(in_features=2000, out_features=1000, bias=True)
#   (relu_out): ReLU()
# )
# Number of parameters:  35065500

# %%
import warnings
warnings.filterwarnings("ignore")

######################################
#  LOSS
######################################

# Root mean squared error
loss_fn = torch.nn.HuberLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0005) 
scheduler = StepLR(optimizer, step_size=100, gamma=0.5)

# Use GPU for training

model = model.to(device)

# Wrap data in a data loader



NUM_GRAPHS_PER_BATCH = 64


loader = DataLoader(train_dataset, 
                    batch_size=NUM_GRAPHS_PER_BATCH, shuffle=True)

validation_loader = DataLoader(validation_dataset, 
                    batch_size=NUM_GRAPHS_PER_BATCH, shuffle=True)

test_loader = DataLoader(test_dataset, 
                         batch_size=NUM_GRAPHS_PER_BATCH, shuffle=True)
SAVE_EVERY_X_EPOCH = 10
REPORT_EVERY_X_EPOCH = 1

def train(loader):
    # Enumerate over the data
    loss_per_batch = np.array([])
    for batch in loader:
        # Use GPU
        batch.to(device)  
        # Reset gradients
        optimizer.zero_grad() 
        # Passing the node features and the connection info
        pred = model(batch.x.float(), batch.edge_index, batch.edge_attr, batch.molecular_weight, batch.batch) 
        # Calculating the loss and gradients
        loss = loss_fn(pred, batch.y)
        loss.backward()  
        # Update using the gradients
        optimizer.step()
        loss_per_batch = np.concatenate((loss_per_batch, np.array([loss.clone().detach().cpu().numpy()])))
    return loss_per_batch

print("Starting training...")

for epoch in range(300):
    scheduler.step()
    loss = train(loader)
    pred_test_similarity = np.array([])
    pred_validation_similarity = np.array([])
   
   
    if epoch % REPORT_EVERY_X_EPOCH == 0:
        for batch in test_loader:
            batch.to(device)  
            pred = model(batch.x.float(), batch.edge_index, batch.edge_attr, batch.molecular_weight, batch.batch)

            batch_similarity = validate_similarities(batch.y.detach().cpu().numpy(),
                                  pred.detach().cpu().numpy(),
                                  mass_pow=1.0, intensity_pow=0.5)

            pred_test_similarity = np.concatenate((pred_test_similarity, batch_similarity))
    
        for batch in validation_loader:
           
            batch.to(device)  
            pred = model(batch.x.float(), batch.edge_index, batch.edge_attr, batch.molecular_weight, batch.batch)

            batch_similarity = validate_similarities(batch.y.detach().cpu().numpy(),
                                  pred.detach().cpu().numpy(),
                                  mass_pow=1.0, intensity_pow=0.5)

            pred_validation_similarity = np.concatenate((pred_validation_similarity, batch_similarity))
            
        
        print(f"Epoch {epoch} | Test DotSimilarity is {pred_test_similarity.mean()}")
        print(f"Epoch {epoch} | Validation DotSimilarity is {pred_validation_similarity.mean()}")
        print(f"Epoch {epoch} | Train Loss {loss.mean()}")
        print()

    
    if epoch % SAVE_EVERY_X_EPOCH == 0:
        SAVE_PATH = f"{epoch}.pt"
            
        # Save model
        torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': loss,
        'metadata': {"loss" : "HuberLoss",
                     "Dataset": "Preprocessed_test_pow_preparation_no_sparse_small",
                     "test_similarities": pred_test_similarity.mean()}
        }, os.path.join(MODEL_SAVE, SAVE_PATH))

        LOSS_FILE = f"all_loss_until_{epoch}.output"
        with open(os.path.join(MODEL_SAVE, LOSS_FILE), 'wb') as fid:
            pickle.dump(loss.mean(), fid)
            fid.close()
# Out:
# Starting training...
# Epoch 0 | Test DotSimilarity is 0.7575590955187312
# Epoch 0 | Validation DotSimilarity is 0.7570808120262554
# Epoch 0 | Train Loss 0.29368624125264664
#
# Epoch 1 | Test DotSimilarity is 0.7736780899462883
# Epoch 1 | Validation DotSimilarity is 0.7740394085129328
# Epoch 1 | Train Loss 0.27286283791980903
#
# Epoch 2 | Test DotSimilarity is 0.7826235766160017
# Epoch 2 | Validation DotSimilarity is 0.7819804544445013
# Epoch 2 | Train Loss 0.26379257940022854
#
# Epoch 3 | Test DotSimilarity is 0.7893297120932488
# Epoch 3 | Validation DotSimilarity is 0.7876204016558318
# Epoch 3 | Train Loss 0.2570771191414507
#
# Epoch 4 | Test DotSimilarity is 0.7943824740690875
# Epoch 4 | Validation DotSimilarity is 0.794442870108146
# Epoch 4 | Train Loss 0.2515146077402022
#
# Epoch 5 | Test DotSimilarity is 0.7991542991346566
# Epoch 5 | Validation DotSimilarity is 0.798042525855848
# Epoch 5 | Train Loss 0.24738780563230559
#
# Epoch 6 | Test DotSimilarity is 0.8025219885316567
# Epoch 6 | Validation DotSimilarity is 0.8021611195130383
# Epoch 6 | Train Loss 0.24356775298203234
#
# Epoch 7 | Test DotSimilarity is 0.804765340296696
# Epoch 7 | Validation DotSimilarity is 0.8049826120823873
# Epoch 7 | Train Loss 0.24028119766648973
#
# Epoch 8 | Test DotSimilarity is 0.8075138587918326
# Epoch 8 | Validation DotSimilarity is 0.807764344373405
# Epoch 8 | Train Loss 0.23702661488477603
#
# Epoch 9 | Test DotSimilarity is 0.8103834057717748
# Epoch 9 | Validation DotSimilarity is 0.8102786589368547
# Epoch 9 | Train Loss 0.2342892157744211
#
# Epoch 10 | Test DotSimilarity is 0.8114571408671418
# Epoch 10 | Validation DotSimilarity is 0.8107589428728958
# Epoch 10 | Train Loss 0.23168287268152077
#
# Epoch 11 | Test DotSimilarity is 0.8142384833432099
# Epoch 11 | Validation DotSimilarity is 0.814167247437057
# Epoch 11 | Train Loss 0.22904692172860877
#
# Epoch 12 | Test DotSimilarity is 0.8167345637498398
# Epoch 12 | Validation DotSimilarity is 0.8156601902667406
# Epoch 12 | Train Loss 0.2266498233869781
#
# Epoch 13 | Test DotSimilarity is 0.8184130943685773
# Epoch 13 | Validation DotSimilarity is 0.8184938610272964
# Epoch 13 | Train Loss 0.2243044364619425
#
# Epoch 14 | Test DotSimilarity is 0.8203763390948119
# Epoch 14 | Validation DotSimilarity is 0.8206258246471876
# Epoch 14 | Train Loss 0.22212961893559302
#
# Epoch 15 | Test DotSimilarity is 0.8219312389461219
# Epoch 15 | Validation DotSimilarity is 0.8211713423776209
# Epoch 15 | Train Loss 0.22003282736841992
#
# Epoch 16 | Test DotSimilarity is 0.8224243339887298
# Epoch 16 | Validation DotSimilarity is 0.8235902062811586
# Epoch 16 | Train Loss 0.21777542453204365
#
# Epoch 17 | Test DotSimilarity is 0.8231187592930798
# Epoch 17 | Validation DotSimilarity is 0.8239760915449835
# Epoch 17 | Train Loss 0.21590432351477643
#
# Epoch 18 | Test DotSimilarity is 0.8255189248328363
# Epoch 18 | Validation DotSimilarity is 0.8253934837455427
# Epoch 18 | Train Loss 0.21383792698963502
#
# Epoch 19 | Test DotSimilarity is 0.8268127607699591
# Epoch 19 | Validation DotSimilarity is 0.8271557764484826
# Epoch 19 | Train Loss 0.2117500714235719
#
# Epoch 20 | Test DotSimilarity is 0.8264646855708255
# Epoch 20 | Validation DotSimilarity is 0.8273885537592643
# Epoch 20 | Train Loss 0.2099014200070372
#
# Epoch 21 | Test DotSimilarity is 0.826766402801848
# Epoch 21 | Validation DotSimilarity is 0.8281774555832359
# Epoch 21 | Train Loss 0.2079862517209038
#
# Epoch 22 | Test DotSimilarity is 0.8290117709848036
# Epoch 22 | Validation DotSimilarity is 0.8298500175701385
# Epoch 22 | Train Loss 0.2063283199510757
#
# Epoch 23 | Test DotSimilarity is 0.8287998779770672
# Epoch 23 | Validation DotSimilarity is 0.8298299739349746
# Epoch 23 | Train Loss 0.20451445889759526
#
# Epoch 24 | Test DotSimilarity is 0.8293659008943618
# Epoch 24 | Validation DotSimilarity is 0.8300185404031254
# Epoch 24 | Train Loss 0.2028003574813585
#
# Epoch 25 | Test DotSimilarity is 0.8312406703605153
# Epoch 25 | Validation DotSimilarity is 0.8318126655741857
# Epoch 25 | Train Loss 0.20109764254998558
#
# Epoch 26 | Test DotSimilarity is 0.8319057795463088
# Epoch 26 | Validation DotSimilarity is 0.832810197217491
# Epoch 26 | Train Loss 0.19941932720350114
#
# Epoch 27 | Test DotSimilarity is 0.8325035809855273
# Epoch 27 | Validation DotSimilarity is 0.8326217842238937
# Epoch 27 | Train Loss 0.1979580481115989
#
# Epoch 28 | Test DotSimilarity is 0.8324192426219063
# Epoch 28 | Validation DotSimilarity is 0.8330476496190168
# Epoch 28 | Train Loss 0.1963305817682597
#
# Epoch 29 | Test DotSimilarity is 0.8331125585966606
# Epoch 29 | Validation DotSimilarity is 0.8337318193687272
# Epoch 29 | Train Loss 0.19474021494155574
#
# Epoch 30 | Test DotSimilarity is 0.833147112561256
# Epoch 30 | Validation DotSimilarity is 0.8341761144324593
# Epoch 30 | Train Loss 0.19319007598478674
#
# Epoch 31 | Test DotSimilarity is 0.8331395601711327
# Epoch 31 | Validation DotSimilarity is 0.8344522510888651
# Epoch 31 | Train Loss 0.19174287493626604
#
# Epoch 32 | Test DotSimilarity is 0.8339357025917631
# Epoch 32 | Validation DotSimilarity is 0.8344020144652022
# Epoch 32 | Train Loss 0.1901982670416162
#
# Epoch 33 | Test DotSimilarity is 0.8356667531654104
# Epoch 33 | Validation DotSimilarity is 0.8360905777211992
# Epoch 33 | Train Loss 0.1888983362766754
#
# Epoch 34 | Test DotSimilarity is 0.8351356702308127
# Epoch 34 | Validation DotSimilarity is 0.8354594655797751
# Epoch 34 | Train Loss 0.18731474171438
#
# Epoch 35 | Test DotSimilarity is 0.8360327374018585
# Epoch 35 | Validation DotSimilarity is 0.8363666830621013
# Epoch 35 | Train Loss 0.18615201107990417
#
# Epoch 36 | Test DotSimilarity is 0.8364952753388175
# Epoch 36 | Validation DotSimilarity is 0.8375893159307397
# Epoch 36 | Train Loss 0.18478320080321667
#
# Epoch 37 | Test DotSimilarity is 0.8357070617797155
# Epoch 37 | Validation DotSimilarity is 0.8372446273915605
# Epoch 37 | Train Loss 0.18356307089404153
#
# Epoch 38 | Test DotSimilarity is 0.8370978282770356
# Epoch 38 | Validation DotSimilarity is 0.8378698507431407
# Epoch 38 | Train Loss 0.18209869675900672
#
# Epoch 39 | Test DotSimilarity is 0.836911740744604
# Epoch 39 | Validation DotSimilarity is 0.8380011847690024
# Epoch 39 | Train Loss 0.18105357960952514
#
# Epoch 40 | Test DotSimilarity is 0.8369391309400246
# Epoch 40 | Validation DotSimilarity is 0.8375536762382293
# Epoch 40 | Train Loss 0.17979521855771197
#
# Epoch 41 | Test DotSimilarity is 0.837145849279037
# Epoch 41 | Validation DotSimilarity is 0.8384204305159039
# Epoch 41 | Train Loss 0.17855979418485357
#
# Epoch 42 | Test DotSimilarity is 0.8377316609035844
# Epoch 42 | Validation DotSimilarity is 0.8390353417734688
# Epoch 42 | Train Loss 0.17753724235277826
#
# Epoch 43 | Test DotSimilarity is 0.8383687127166273
# Epoch 43 | Validation DotSimilarity is 0.8392705388721637
# Epoch 43 | Train Loss 0.17627398868213015
#
# Epoch 44 | Test DotSimilarity is 0.8388421776589216
# Epoch 44 | Validation DotSimilarity is 0.8390422344986928
# Epoch 44 | Train Loss 0.17520529568124493
#
# Epoch 45 | Test DotSimilarity is 0.837846571781395
# Epoch 45 | Validation DotSimilarity is 0.839078219227745
# Epoch 45 | Train Loss 0.1742675718133981
#
# Epoch 46 | Test DotSimilarity is 0.8388113800176034
# Epoch 46 | Validation DotSimilarity is 0.8398859068774939
# Epoch 46 | Train Loss 0.1731552505248959
#
# Epoch 47 | Test DotSimilarity is 0.8393365092210031
# Epoch 47 | Validation DotSimilarity is 0.8394845662478434
# Epoch 47 | Train Loss 0.17224381259141458
#
# Epoch 48 | Test DotSimilarity is 0.8385852375900449
# Epoch 48 | Validation DotSimilarity is 0.8395087200065297
# Epoch 48 | Train Loss 0.17129746501035845
#
# Epoch 49 | Test DotSimilarity is 0.8392952658111404
# Epoch 49 | Validation DotSimilarity is 0.839745904963697
# Epoch 49 | Train Loss 0.1700438859927325
#
# Epoch 50 | Test DotSimilarity is 0.8391219111114122
# Epoch 50 | Validation DotSimilarity is 0.8396716868680362
# Epoch 50 | Train Loss 0.16936318745496753
#
# Epoch 51 | Test DotSimilarity is 0.8404012809102296
# Epoch 51 | Validation DotSimilarity is 0.840977995226283
# Epoch 51 | Train Loss 0.1683121600645221
#
# Epoch 52 | Test DotSimilarity is 0.8397111355977535
# Epoch 52 | Validation DotSimilarity is 0.8402357784807649
# Epoch 52 | Train Loss 0.16740040031212836
#
# Epoch 53 | Test DotSimilarity is 0.8395308089614922
# Epoch 53 | Validation DotSimilarity is 0.8401737517666654
# Epoch 53 | Train Loss 0.16647451505405728
#
# Epoch 54 | Test DotSimilarity is 0.8405194348437093
# Epoch 54 | Validation DotSimilarity is 0.8408053423098175
# Epoch 54 | Train Loss 0.1657533923941302
#
# Epoch 55 | Test DotSimilarity is 0.8397764139641815
# Epoch 55 | Validation DotSimilarity is 0.8406055673856521
# Epoch 55 | Train Loss 0.16486976032703976
#
# Epoch 56 | Test DotSimilarity is 0.8410725150521313
# Epoch 56 | Validation DotSimilarity is 0.8415115482672765
# Epoch 56 | Train Loss 0.16402506082147456
#
# Epoch 57 | Test DotSimilarity is 0.8399775446093496
# Epoch 57 | Validation DotSimilarity is 0.8415481759161325
# Epoch 57 | Train Loss 0.16319738147076562
#
# Epoch 58 | Test DotSimilarity is 0.8411579362480296
# Epoch 58 | Validation DotSimilarity is 0.8426458364615526
# Epoch 58 | Train Loss 0.16246988911197685
#
# Epoch 59 | Test DotSimilarity is 0.8404999174537765
# Epoch 59 | Validation DotSimilarity is 0.8407278746369115
# Epoch 59 | Train Loss 0.16164677972351502
#
# Epoch 60 | Test DotSimilarity is 0.8400365641516724
# Epoch 60 | Validation DotSimilarity is 0.8408351149454771
# Epoch 60 | Train Loss 0.1609223779326488
#
# Epoch 61 | Test DotSimilarity is 0.8411962272809127
# Epoch 61 | Validation DotSimilarity is 0.8414712326160013
# Epoch 61 | Train Loss 0.16016052536430506
#
# Epoch 62 | Test DotSimilarity is 0.8403152314620472
# Epoch 62 | Validation DotSimilarity is 0.8412841660503414
# Epoch 62 | Train Loss 0.15942664751614638
#
# Epoch 63 | Test DotSimilarity is 0.8406457948612799
# Epoch 63 | Validation DotSimilarity is 0.8416609842683589
# Epoch 63 | Train Loss 0.15870295035974394
#
# Epoch 64 | Test DotSimilarity is 0.8406261527004771
# Epoch 64 | Validation DotSimilarity is 0.84182828906134
# Epoch 64 | Train Loss 0.1580127118548386
#
# Epoch 65 | Test DotSimilarity is 0.8415771406981012
# Epoch 65 | Validation DotSimilarity is 0.8419295984538109
# Epoch 65 | Train Loss 0.15721106823498324
#
# Epoch 66 | Test DotSimilarity is 0.8413714182083748
# Epoch 66 | Validation DotSimilarity is 0.842058129895357
# Epoch 66 | Train Loss 0.15670474285577468
#
# Epoch 67 | Test DotSimilarity is 0.8417508526824072
# Epoch 67 | Validation DotSimilarity is 0.8424828650484818
# Epoch 67 | Train Loss 0.15597528903514973
#
# Epoch 68 | Test DotSimilarity is 0.8422867914115201
# Epoch 68 | Validation DotSimilarity is 0.8419471643603452
# Epoch 68 | Train Loss 0.1553389862236712
#
# Epoch 69 | Test DotSimilarity is 0.8408608000751803
# Epoch 69 | Validation DotSimilarity is 0.8418822117887412
# Epoch 69 | Train Loss 0.15477140604011147
#
# Epoch 70 | Test DotSimilarity is 0.841693886707936
# Epoch 70 | Validation DotSimilarity is 0.8431395946242172
# Epoch 70 | Train Loss 0.1540451302382537
#
# Epoch 71 | Test DotSimilarity is 0.8415396099565751
# Epoch 71 | Validation DotSimilarity is 0.8426138538046469
# Epoch 71 | Train Loss 0.15354966834183778
#
# Epoch 72 | Test DotSimilarity is 0.8418285831117879
# Epoch 72 | Validation DotSimilarity is 0.8425680118937189
# Epoch 72 | Train Loss 0.1528962700688299
#
# Epoch 73 | Test DotSimilarity is 0.8423083180460257
# Epoch 73 | Validation DotSimilarity is 0.8425613619692994
# Epoch 73 | Train Loss 0.15234871599098535
#
# Epoch 74 | Test DotSimilarity is 0.8422792234244505
# Epoch 74 | Validation DotSimilarity is 0.8431593499821997
# Epoch 74 | Train Loss 0.15184005836349412
#
# Epoch 75 | Test DotSimilarity is 0.842365213734762
# Epoch 75 | Validation DotSimilarity is 0.8429040840012488
# Epoch 75 | Train Loss 0.1510194674478737
#
# Epoch 76 | Test DotSimilarity is 0.8426078091736894
# Epoch 76 | Validation DotSimilarity is 0.8433222995363027
# Epoch 76 | Train Loss 0.1507003812196304
#
# Epoch 77 | Test DotSimilarity is 0.8420814048272331
# Epoch 77 | Validation DotSimilarity is 0.8432651045769275
# Epoch 77 | Train Loss 0.15002548941352847
#
# Epoch 78 | Test DotSimilarity is 0.8426329036772411
# Epoch 78 | Validation DotSimilarity is 0.8432078965136145
# Epoch 78 | Train Loss 0.14960039475599782
#
# Epoch 79 | Test DotSimilarity is 0.8425816039734165
# Epoch 79 | Validation DotSimilarity is 0.8433926314956518
# Epoch 79 | Train Loss 0.14904809503544664
#
# Epoch 80 | Test DotSimilarity is 0.8433957612111442
# Epoch 80 | Validation DotSimilarity is 0.8441564952719042
# Epoch 80 | Train Loss 0.1485000181883195
#
# Epoch 81 | Test DotSimilarity is 0.8432391775883913
# Epoch 81 | Validation DotSimilarity is 0.8437799580162649
# Epoch 81 | Train Loss 0.14797952197859354
#
# Epoch 82 | Test DotSimilarity is 0.8430430046759215
# Epoch 82 | Validation DotSimilarity is 0.8437989047472875
# Epoch 82 | Train Loss 0.1475649184545713
#
# Epoch 83 | Test DotSimilarity is 0.843209168717817
# Epoch 83 | Validation DotSimilarity is 0.8444424000104064
# Epoch 83 | Train Loss 0.14699907616565483
#
# Epoch 84 | Test DotSimilarity is 0.843272756091672
# Epoch 84 | Validation DotSimilarity is 0.8437813213143918
# Epoch 84 | Train Loss 0.14656527996994398
#
# Epoch 85 | Test DotSimilarity is 0.8428747506387213
# Epoch 85 | Validation DotSimilarity is 0.8442835271856584
# Epoch 85 | Train Loss 0.1461785533279005
#
# Epoch 86 | Test DotSimilarity is 0.8425710632125502
# Epoch 86 | Validation DotSimilarity is 0.8434194153177261
# Epoch 86 | Train Loss 0.1456756077492081
#
# Epoch 87 | Test DotSimilarity is 0.8427607563735928
# Epoch 87 | Validation DotSimilarity is 0.842793776932211
# Epoch 87 | Train Loss 0.14521101050613017
#
# Epoch 88 | Test DotSimilarity is 0.8430166719035896
# Epoch 88 | Validation DotSimilarity is 0.8432335697300783
# Epoch 88 | Train Loss 0.1447349882452722
#
# Epoch 89 | Test DotSimilarity is 0.8436001497349777
# Epoch 89 | Validation DotSimilarity is 0.8440078282042978
# Epoch 89 | Train Loss 0.14435716386803835
#
# Epoch 90 | Test DotSimilarity is 0.8435051732062959
# Epoch 90 | Validation DotSimilarity is 0.8440276670321185
# Epoch 90 | Train Loss 0.14399978275944347
#
# Epoch 91 | Test DotSimilarity is 0.8442948856920026
# Epoch 91 | Validation DotSimilarity is 0.8442677483275738
# Epoch 91 | Train Loss 0.14350972787577884
#
# Epoch 92 | Test DotSimilarity is 0.8443763583053587
# Epoch 92 | Validation DotSimilarity is 0.8446107059789137
# Epoch 92 | Train Loss 0.1431167400394244
#
# Epoch 93 | Test DotSimilarity is 0.8426103568814209
# Epoch 93 | Validation DotSimilarity is 0.843215720322515
# Epoch 93 | Train Loss 0.14275163704645635
#
# Epoch 94 | Test DotSimilarity is 0.8431127966089823
# Epoch 94 | Validation DotSimilarity is 0.8442593401801951
# Epoch 94 | Train Loss 0.1422315437907607
#
# Epoch 95 | Test DotSimilarity is 0.844227717832855
# Epoch 95 | Validation DotSimilarity is 0.8453250418768774
# Epoch 95 | Train Loss 0.14192128977977783
#
# Epoch 96 | Test DotSimilarity is 0.8442864749577162
# Epoch 96 | Validation DotSimilarity is 0.8453372267551633
# Epoch 96 | Train Loss 0.1415342785012414
#
# Epoch 97 | Test DotSimilarity is 0.8437609081234636
# Epoch 97 | Validation DotSimilarity is 0.8437036119328608
# Epoch 97 | Train Loss 0.1410766002283598
#
# Epoch 98 | Test DotSimilarity is 0.8451949465027919
# Epoch 98 | Validation DotSimilarity is 0.8451927179027052
# Epoch 98 | Train Loss 0.1407620617270195
#
# Epoch 99 | Test DotSimilarity is 0.8449936790294375
# Epoch 99 | Validation DotSimilarity is 0.8471266969519929
# Epoch 99 | Train Loss 0.13585230358180989
#
# Epoch 100 | Test DotSimilarity is 0.8453523662582145
# Epoch 100 | Validation DotSimilarity is 0.846480199276107
# Epoch 100 | Train Loss 0.13454892094260903
#
# Epoch 101 | Test DotSimilarity is 0.8462516973633194
# Epoch 101 | Validation DotSimilarity is 0.8468596393083458
# Epoch 101 | Train Loss 0.13399483901992948
#
# Epoch 102 | Test DotSimilarity is 0.8456086070441353
# Epoch 102 | Validation DotSimilarity is 0.8464039400671695
# Epoch 102 | Train Loss 0.13354338248520278
#
# Epoch 103 | Test DotSimilarity is 0.8456453671063904
# Epoch 103 | Validation DotSimilarity is 0.8461438794403406
# Epoch 103 | Train Loss 0.13316971391036267
#
# Epoch 104 | Test DotSimilarity is 0.8453775412605435
# Epoch 104 | Validation DotSimilarity is 0.8453891256035382
# Epoch 104 | Train Loss 0.13279104576346454
#
# Epoch 105 | Test DotSimilarity is 0.8455823962132385
# Epoch 105 | Validation DotSimilarity is 0.8465428408272139
# Epoch 105 | Train Loss 0.1324647846746672
#
# Epoch 106 | Test DotSimilarity is 0.8454306570514013
# Epoch 106 | Validation DotSimilarity is 0.8457736398550736
# Epoch 106 | Train Loss 0.1322575354608328
#
# Epoch 107 | Test DotSimilarity is 0.8456713405493701
# Epoch 107 | Validation DotSimilarity is 0.8463498378943229
# Epoch 107 | Train Loss 0.13203200735443937
#
# Epoch 108 | Test DotSimilarity is 0.8451151974345141
# Epoch 108 | Validation DotSimilarity is 0.8460771732273908
# Epoch 108 | Train Loss 0.13167977396147704
#
# Epoch 109 | Test DotSimilarity is 0.8447510808632105
# Epoch 109 | Validation DotSimilarity is 0.8461407520619987
# Epoch 109 | Train Loss 0.13138774207954057
#
# Epoch 110 | Test DotSimilarity is 0.8456890103560291
# Epoch 110 | Validation DotSimilarity is 0.8464019196373621
# Epoch 110 | Train Loss 0.13120343363336345
#
# Epoch 111 | Test DotSimilarity is 0.8450690546501939
# Epoch 111 | Validation DotSimilarity is 0.8464323393849916
# Epoch 111 | Train Loss 0.13097970662398176
#
# Epoch 112 | Test DotSimilarity is 0.8453915323785653
# Epoch 112 | Validation DotSimilarity is 0.8459250341953324
# Epoch 112 | Train Loss 0.13070029102999584
#
# Epoch 113 | Test DotSimilarity is 0.845286450247657
# Epoch 113 | Validation DotSimilarity is 0.8457857775416349
# Epoch 113 | Train Loss 0.13044726501994752
#
# Epoch 114 | Test DotSimilarity is 0.8456155467908145
# Epoch 114 | Validation DotSimilarity is 0.8467282839811469
# Epoch 114 | Train Loss 0.13028643078853372
#
# Epoch 115 | Test DotSimilarity is 0.8462674062393678
# Epoch 115 | Validation DotSimilarity is 0.8466823608125904
# Epoch 115 | Train Loss 0.1299783399592391
#
# Epoch 116 | Test DotSimilarity is 0.8450578191523495
# Epoch 116 | Validation DotSimilarity is 0.8454650004617863
# Epoch 116 | Train Loss 0.12986030050525255
#
# Epoch 117 | Test DotSimilarity is 0.8456745145756702
# Epoch 117 | Validation DotSimilarity is 0.8464623247652815
# Epoch 117 | Train Loss 0.12964483344153221
#
# Epoch 118 | Test DotSimilarity is 0.8455508796543855
# Epoch 118 | Validation DotSimilarity is 0.8468243630388217
# Epoch 118 | Train Loss 0.1294324463240878
#
# Epoch 119 | Test DotSimilarity is 0.8457979394020398
# Epoch 119 | Validation DotSimilarity is 0.8461438342132281
# Epoch 119 | Train Loss 0.12921187817245539
#
# Epoch 120 | Test DotSimilarity is 0.845126036259536
# Epoch 120 | Validation DotSimilarity is 0.8461872861102647
# Epoch 120 | Train Loss 0.12905507976844863
#
# Epoch 121 | Test DotSimilarity is 0.8454448426293469
# Epoch 121 | Validation DotSimilarity is 0.8467646826276108
# Epoch 121 | Train Loss 0.1288310132436652
#
# Epoch 122 | Test DotSimilarity is 0.845694190618406
# Epoch 122 | Validation DotSimilarity is 0.8466325628907169
# Epoch 122 | Train Loss 0.1286219419060614
#
# Epoch 123 | Test DotSimilarity is 0.845340693703439
# Epoch 123 | Validation DotSimilarity is 0.8463774530338624
# Epoch 123 | Train Loss 0.12837790991086012
#
# Epoch 124 | Test DotSimilarity is 0.84521310442588
# Epoch 124 | Validation DotSimilarity is 0.8459527153064502
# Epoch 124 | Train Loss 0.12829483937846095
#
# Epoch 125 | Test DotSimilarity is 0.8453737117233472
# Epoch 125 | Validation DotSimilarity is 0.8462039027662112
# Epoch 125 | Train Loss 0.1280768701220574
#
# Epoch 126 | Test DotSimilarity is 0.8456797661522578
# Epoch 126 | Validation DotSimilarity is 0.8467780657772153
# Epoch 126 | Train Loss 0.12784172730597484
#
# Epoch 127 | Test DotSimilarity is 0.8456915476021081
# Epoch 127 | Validation DotSimilarity is 0.8464261232045767
# Epoch 127 | Train Loss 0.12766987737971752
#
# Epoch 128 | Test DotSimilarity is 0.845430581693519
# Epoch 128 | Validation DotSimilarity is 0.8464184112762745
# Epoch 128 | Train Loss 0.1275369991732269
#
# Epoch 129 | Test DotSimilarity is 0.8448802925727046
# Epoch 129 | Validation DotSimilarity is 0.8463792106175082
# Epoch 129 | Train Loss 0.12745388941984517
#
# Epoch 130 | Test DotSimilarity is 0.8454426945990512
# Epoch 130 | Validation DotSimilarity is 0.8462121105231512
# Epoch 130 | Train Loss 0.1272056687882784
#
# Epoch 131 | Test DotSimilarity is 0.8454693774162845
# Epoch 131 | Validation DotSimilarity is 0.8463695239025332
# Epoch 131 | Train Loss 0.12705756181388111
#
# Epoch 132 | Test DotSimilarity is 0.8458575292619623
# Epoch 132 | Validation DotSimilarity is 0.8460418137512643
# Epoch 132 | Train Loss 0.1268359541541318
#
# Epoch 133 | Test DotSimilarity is 0.8456027601497496
# Epoch 133 | Validation DotSimilarity is 0.8464926445843448
# Epoch 133 | Train Loss 0.12672006929492666
#
# Epoch 134 | Test DotSimilarity is 0.8457972013866343
# Epoch 134 | Validation DotSimilarity is 0.8462792036372266
# Epoch 134 | Train Loss 0.12655763148296367
#
# Epoch 135 | Test DotSimilarity is 0.8461317365153751
# Epoch 135 | Validation DotSimilarity is 0.8464327463229704
# Epoch 135 | Train Loss 0.12633947049903121
#
# Epoch 136 | Test DotSimilarity is 0.8457098165190826
# Epoch 136 | Validation DotSimilarity is 0.846282785591657
# Epoch 136 | Train Loss 0.12620616613072072
#
# Epoch 137 | Test DotSimilarity is 0.8454224357532893
# Epoch 137 | Validation DotSimilarity is 0.8465318664794872
# Epoch 137 | Train Loss 0.12602793091520822
#
# Epoch 138 | Test DotSimilarity is 0.8458439631311158
# Epoch 138 | Validation DotSimilarity is 0.8467442976216882
# Epoch 138 | Train Loss 0.12585279836968383
#
# Epoch 139 | Test DotSimilarity is 0.8460139868854436
# Epoch 139 | Validation DotSimilarity is 0.8458954068705865
# Epoch 139 | Train Loss 0.12578156982912103
#
# Epoch 140 | Test DotSimilarity is 0.8451415652571445
# Epoch 140 | Validation DotSimilarity is 0.845950172886797
# Epoch 140 | Train Loss 0.12559056378426922
#
# Epoch 141 | Test DotSimilarity is 0.8460034047110389
# Epoch 141 | Validation DotSimilarity is 0.8464810294027322
# Epoch 141 | Train Loss 0.12539274159439456
#
# Epoch 142 | Test DotSimilarity is 0.8458280481932999
# Epoch 142 | Validation DotSimilarity is 0.8467728772307359
# Epoch 142 | Train Loss 0.12526875976729535
#
# Epoch 143 | Test DotSimilarity is 0.8452860785780838
# Epoch 143 | Validation DotSimilarity is 0.846279371543731
# Epoch 143 | Train Loss 0.12513010995471147
#
# Epoch 144 | Test DotSimilarity is 0.8455842818987594
# Epoch 144 | Validation DotSimilarity is 0.8464171601850343
# Epoch 144 | Train Loss 0.1250135592990274
#
# Epoch 145 | Test DotSimilarity is 0.8459403618925969
# Epoch 145 | Validation DotSimilarity is 0.8465446322014292
# Epoch 145 | Train Loss 0.12486665943277443
#
# Epoch 146 | Test DotSimilarity is 0.8459059482347464
# Epoch 146 | Validation DotSimilarity is 0.8463710208940378
# Epoch 146 | Train Loss 0.1246820753785537
#
# Epoch 147 | Test DotSimilarity is 0.8456905690181474
# Epoch 147 | Validation DotSimilarity is 0.8460318512146314
# Epoch 147 | Train Loss 0.12451548745056941
#
# Epoch 148 | Test DotSimilarity is 0.845609831189281
# Epoch 148 | Validation DotSimilarity is 0.8464733604347479
# Epoch 148 | Train Loss 0.1244312306073486
#
# Epoch 149 | Test DotSimilarity is 0.8461923526317138
# Epoch 149 | Validation DotSimilarity is 0.8465361014510742
# Epoch 149 | Train Loss 0.12429742687077648
#
# Epoch 150 | Test DotSimilarity is 0.846032804546208
# Epoch 150 | Validation DotSimilarity is 0.8466906776925123
# Epoch 150 | Train Loss 0.1241615468164949
#
# Epoch 151 | Test DotSimilarity is 0.8459471014566299
# Epoch 151 | Validation DotSimilarity is 0.8465083722696604
# Epoch 151 | Train Loss 0.12388829356527745
#
# Epoch 152 | Test DotSimilarity is 0.8456951001409756
# Epoch 152 | Validation DotSimilarity is 0.8466363624765961
# Epoch 152 | Train Loss 0.12385854679769906
#
# Epoch 153 | Test DotSimilarity is 0.84579686346222
# Epoch 153 | Validation DotSimilarity is 0.8468257699590794
# Epoch 153 | Train Loss 0.12361419174111402
#
# Epoch 154 | Test DotSimilarity is 0.845783939797488
# Epoch 154 | Validation DotSimilarity is 0.8466077918222585
# Epoch 154 | Train Loss 0.12358445615442792
#
# Epoch 155 | Test DotSimilarity is 0.8453808817722634
# Epoch 155 | Validation DotSimilarity is 0.8461881040256749
# Epoch 155 | Train Loss 0.12341239016845026
#
# Epoch 156 | Test DotSimilarity is 0.8458609146193022
# Epoch 156 | Validation DotSimilarity is 0.8465572991454239
# Epoch 156 | Train Loss 0.12331368383478321
#
# Epoch 157 | Test DotSimilarity is 0.8463844498775638
# Epoch 157 | Validation DotSimilarity is 0.8465174809924781
# Epoch 157 | Train Loss 0.12318724001033818
#
# Epoch 158 | Test DotSimilarity is 0.8450396772641847
# Epoch 158 | Validation DotSimilarity is 0.8461214272760975
# Epoch 158 | Train Loss 0.12302107552040445
#
# Epoch 159 | Test DotSimilarity is 0.84583972897036
# Epoch 159 | Validation DotSimilarity is 0.8468876575221682
# Epoch 159 | Train Loss 0.12282444330730652
#
# Epoch 160 | Test DotSimilarity is 0.8464511291691308
# Epoch 160 | Validation DotSimilarity is 0.8467696674089596
# Epoch 160 | Train Loss 0.12281681449268865
#
# Epoch 161 | Test DotSimilarity is 0.8455889267436134
# Epoch 161 | Validation DotSimilarity is 0.8465538389529287
# Epoch 161 | Train Loss 0.12267173194817012
#
# Epoch 162 | Test DotSimilarity is 0.8463325505319128
# Epoch 162 | Validation DotSimilarity is 0.8466587901301217
# Epoch 162 | Train Loss 0.12247691951023172
#
# Epoch 163 | Test DotSimilarity is 0.8458800614444506
# Epoch 163 | Validation DotSimilarity is 0.8470236340991886
# Epoch 163 | Train Loss 0.12235678753899636
#
# Epoch 164 | Test DotSimilarity is 0.8462578284305404
# Epoch 164 | Validation DotSimilarity is 0.8468952978334277
# Epoch 164 | Train Loss 0.12230267119930249
#
# Epoch 165 | Test DotSimilarity is 0.8459212985522949
# Epoch 165 | Validation DotSimilarity is 0.8468878426102646
# Epoch 165 | Train Loss 0.12223742130727215
#
# Epoch 166 | Test DotSimilarity is 0.8459932118413431
# Epoch 166 | Validation DotSimilarity is 0.8468362853986371
# Epoch 166 | Train Loss 0.12200923337011883
#
# Epoch 167 | Test DotSimilarity is 0.8456318154697281
# Epoch 167 | Validation DotSimilarity is 0.8465842036609749
# Epoch 167 | Train Loss 0.12195749444689827
#
# Epoch 168 | Test DotSimilarity is 0.8463482528358942
# Epoch 168 | Validation DotSimilarity is 0.8469388788926059
# Epoch 168 | Train Loss 0.12177333838478498
#
# Epoch 169 | Test DotSimilarity is 0.8462909817103773
# Epoch 169 | Validation DotSimilarity is 0.8468102101531233
# Epoch 169 | Train Loss 0.12163300242872359
#
# Epoch 170 | Test DotSimilarity is 0.845445770439665
# Epoch 170 | Validation DotSimilarity is 0.8462923571180349
# Epoch 170 | Train Loss 0.1216149151670584
#
# Epoch 171 | Test DotSimilarity is 0.8454527863303963
# Epoch 171 | Validation DotSimilarity is 0.8463446721364165
# Epoch 171 | Train Loss 0.1213881862887974
#
# Epoch 172 | Test DotSimilarity is 0.8457550297113077
# Epoch 172 | Validation DotSimilarity is 0.8463569888166147
# Epoch 172 | Train Loss 0.12136085305600568
#
# Epoch 173 | Test DotSimilarity is 0.8459695450586973
# Epoch 173 | Validation DotSimilarity is 0.8461751647375888
# Epoch 173 | Train Loss 0.12116696098466455
#
# Epoch 174 | Test DotSimilarity is 0.8459502037557235
# Epoch 174 | Validation DotSimilarity is 0.8462509957860791
# Epoch 174 | Train Loss 0.12114344743843801
#
# Epoch 175 | Test DotSimilarity is 0.8461808322774971
# Epoch 175 | Validation DotSimilarity is 0.8467497074789321
# Epoch 175 | Train Loss 0.12099475473706656
#
# Epoch 176 | Test DotSimilarity is 0.8462971592490388
# Epoch 176 | Validation DotSimilarity is 0.8469314626364758
# Epoch 176 | Train Loss 0.12089924351124424
#
# Epoch 177 | Test DotSimilarity is 0.8459682765138464
# Epoch 177 | Validation DotSimilarity is 0.8469661696258807
# Epoch 177 | Train Loss 0.12074720723476252
#
# Epoch 178 | Test DotSimilarity is 0.8459909557267427
# Epoch 178 | Validation DotSimilarity is 0.8461241131050156
# Epoch 178 | Train Loss 0.12066934319829513
#
# Epoch 179 | Test DotSimilarity is 0.8453015070802837
# Epoch 179 | Validation DotSimilarity is 0.8463680551577858
# Epoch 179 | Train Loss 0.12061367998839256
#
# Epoch 180 | Test DotSimilarity is 0.8459491487411939
# Epoch 180 | Validation DotSimilarity is 0.8463333132090167
# Epoch 180 | Train Loss 0.1205210130240541
#
# Epoch 181 | Test DotSimilarity is 0.8461269197127105
# Epoch 181 | Validation DotSimilarity is 0.8470975640153445
# Epoch 181 | Train Loss 0.12044826924899293
#
# Epoch 182 | Test DotSimilarity is 0.8459937445223658
# Epoch 182 | Validation DotSimilarity is 0.8461676499739955
# Epoch 182 | Train Loss 0.12034813123810716
#
# Epoch 183 | Test DotSimilarity is 0.8465608785515822
# Epoch 183 | Validation DotSimilarity is 0.8466592655264438
# Epoch 183 | Train Loss 0.12018846193905339
#
# Epoch 184 | Test DotSimilarity is 0.8457123029991933
# Epoch 184 | Validation DotSimilarity is 0.8469894322616496
# Epoch 184 | Train Loss 0.12007408326127482
#
# Epoch 185 | Test DotSimilarity is 0.8467430728956536
# Epoch 185 | Validation DotSimilarity is 0.8475051140779444
# Epoch 185 | Train Loss 0.11992721865362724
#
# Epoch 186 | Test DotSimilarity is 0.8462816626153864
# Epoch 186 | Validation DotSimilarity is 0.8468617447999761
# Epoch 186 | Train Loss 0.11982354238610074
#
# Epoch 187 | Test DotSimilarity is 0.8459282996851205
# Epoch 187 | Validation DotSimilarity is 0.8466300093898742
# Epoch 187 | Train Loss 0.11980773190650038
#
# Epoch 188 | Test DotSimilarity is 0.8465772034887137
# Epoch 188 | Validation DotSimilarity is 0.847240264282098
# Epoch 188 | Train Loss 0.11973545969145741
#
# Epoch 189 | Test DotSimilarity is 0.8453789661381523
# Epoch 189 | Validation DotSimilarity is 0.845516108444897
# Epoch 189 | Train Loss 0.11966900404432511
#
# Epoch 190 | Test DotSimilarity is 0.84577975555517
# Epoch 190 | Validation DotSimilarity is 0.8461212044552547
# Epoch 190 | Train Loss 0.11964271374129208
#
# Epoch 191 | Test DotSimilarity is 0.845735904650997
# Epoch 191 | Validation DotSimilarity is 0.8465963991853831
# Epoch 191 | Train Loss 0.11943792359138478
#
# Epoch 192 | Test DotSimilarity is 0.8469619597828356
# Epoch 192 | Validation DotSimilarity is 0.846919290152384
# Epoch 192 | Train Loss 0.11935242638085446
#
# Epoch 193 | Test DotSimilarity is 0.846229967365972
# Epoch 193 | Validation DotSimilarity is 0.8466456816832324
# Epoch 193 | Train Loss 0.11925570916574539
#
# Epoch 194 | Test DotSimilarity is 0.8465421715254368
# Epoch 194 | Validation DotSimilarity is 0.8469461666980506
# Epoch 194 | Train Loss 0.11922440514602671
#
# Epoch 195 | Test DotSimilarity is 0.8463511848303107
# Epoch 195 | Validation DotSimilarity is 0.8467782530713557
# Epoch 195 | Train Loss 0.1190712783351039
#
# Epoch 196 | Test DotSimilarity is 0.8459691836658326
# Epoch 196 | Validation DotSimilarity is 0.8465662123573576
# Epoch 196 | Train Loss 0.11898463207064995
#
# Epoch 197 | Test DotSimilarity is 0.8462283354901994
# Epoch 197 | Validation DotSimilarity is 0.8465468223870753
# Epoch 197 | Train Loss 0.11892150933113613
#
# Epoch 198 | Test DotSimilarity is 0.8468359405769154
# Epoch 198 | Validation DotSimilarity is 0.8466500298013919
# Epoch 198 | Train Loss 0.11874941229420236
#
# Epoch 199 | Test DotSimilarity is 0.8460276720195721
# Epoch 199 | Validation DotSimilarity is 0.8474256997416926
# Epoch 199 | Train Loss 0.11666844518805318
#
# Epoch 200 | Test DotSimilarity is 0.8466769112827446
# Epoch 200 | Validation DotSimilarity is 0.8471743849299738
# Epoch 200 | Train Loss 0.11611059188585215
#
# Epoch 201 | Test DotSimilarity is 0.8469174822469219
# Epoch 201 | Validation DotSimilarity is 0.8466958625273503
# Epoch 201 | Train Loss 0.11592396124014871
#
# Epoch 202 | Test DotSimilarity is 0.8465785346413548
# Epoch 202 | Validation DotSimilarity is 0.8473330660171187
# Epoch 202 | Train Loss 0.11564801726125433
#
# Epoch 203 | Test DotSimilarity is 0.8469434426925866
# Epoch 203 | Validation DotSimilarity is 0.8472925521593717
# Epoch 203 | Train Loss 0.11551570987848134
#
# Epoch 204 | Test DotSimilarity is 0.8462087956049296
# Epoch 204 | Validation DotSimilarity is 0.8468210154440668
# Epoch 204 | Train Loss 0.11543538863962938
#
# Epoch 205 | Test DotSimilarity is 0.8471638000413441
# Epoch 205 | Validation DotSimilarity is 0.8473092875331868
# Epoch 205 | Train Loss 0.11530365386589332
#
# Epoch 206 | Test DotSimilarity is 0.8466488683697518
# Epoch 206 | Validation DotSimilarity is 0.84734245222756
# Epoch 206 | Train Loss 0.11520104367219407
#
# Epoch 207 | Test DotSimilarity is 0.8467543868420424
# Epoch 207 | Validation DotSimilarity is 0.8475969048545691
# Epoch 207 | Train Loss 0.1150692639580736
#
# Epoch 208 | Test DotSimilarity is 0.8470634259465026
# Epoch 208 | Validation DotSimilarity is 0.8471967053697183
# Epoch 208 | Train Loss 0.11498583388267827
#
# Epoch 209 | Test DotSimilarity is 0.8467944874727509
# Epoch 209 | Validation DotSimilarity is 0.8472586693292411
# Epoch 209 | Train Loss 0.11490932763711728
#
# Epoch 210 | Test DotSimilarity is 0.8468591163257412
# Epoch 210 | Validation DotSimilarity is 0.8471491130505807
# Epoch 210 | Train Loss 0.11477691563278968
#
# Epoch 211 | Test DotSimilarity is 0.8466916040543336
# Epoch 211 | Validation DotSimilarity is 0.8476324020066273
# Epoch 211 | Train Loss 0.11471825818234874
#
# Epoch 212 | Test DotSimilarity is 0.8465710590593233
# Epoch 212 | Validation DotSimilarity is 0.8474020220112417
# Epoch 212 | Train Loss 0.11462138867639908
#
# Epoch 213 | Test DotSimilarity is 0.8467517477534551
# Epoch 213 | Validation DotSimilarity is 0.8468116072502546
# Epoch 213 | Train Loss 0.11454546299368731
#
# Epoch 214 | Test DotSimilarity is 0.8466620513938246
# Epoch 214 | Validation DotSimilarity is 0.8471871605317548
# Epoch 214 | Train Loss 0.11447514999700087
#
# Epoch 215 | Test DotSimilarity is 0.8466666784307446
# Epoch 215 | Validation DotSimilarity is 0.8475269972920095
# Epoch 215 | Train Loss 0.11444067454157549
#
# Epoch 216 | Test DotSimilarity is 0.8469569082596418
# Epoch 216 | Validation DotSimilarity is 0.8474911979042726
# Epoch 216 | Train Loss 0.11432771435022562
#
# Epoch 217 | Test DotSimilarity is 0.8469594388753774
# Epoch 217 | Validation DotSimilarity is 0.8477106950611435
# Epoch 217 | Train Loss 0.11429320925496801
#
# Epoch 218 | Test DotSimilarity is 0.8462106474093236
# Epoch 218 | Validation DotSimilarity is 0.846855293090245
# Epoch 218 | Train Loss 0.11420036693039456
#
# Epoch 219 | Test DotSimilarity is 0.8467013918395482
# Epoch 219 | Validation DotSimilarity is 0.8474017906517675
# Epoch 219 | Train Loss 0.11421366205841373
#
# Epoch 220 | Test DotSimilarity is 0.8465128206103134
# Epoch 220 | Validation DotSimilarity is 0.8474272286100181
# Epoch 220 | Train Loss 0.1140730814684081
#
# Epoch 221 | Test DotSimilarity is 0.8468365348456387
# Epoch 221 | Validation DotSimilarity is 0.8469302730466522
# Epoch 221 | Train Loss 0.11404175731621
#
# Epoch 222 | Test DotSimilarity is 0.8467485143909411
# Epoch 222 | Validation DotSimilarity is 0.8472707338864446
# Epoch 222 | Train Loss 0.11401407502555341
#
# Epoch 223 | Test DotSimilarity is 0.8466433611249573
# Epoch 223 | Validation DotSimilarity is 0.8476083939952421
# Epoch 223 | Train Loss 0.11391938869455256
#
# Epoch 224 | Test DotSimilarity is 0.8466408499585983
# Epoch 224 | Validation DotSimilarity is 0.8470711083994774
# Epoch 224 | Train Loss 0.1137803936952688
#
# Epoch 225 | Test DotSimilarity is 0.8468460767757017
# Epoch 225 | Validation DotSimilarity is 0.8475943996280068
# Epoch 225 | Train Loss 0.11379796905503099
#
# Epoch 226 | Test DotSimilarity is 0.8465586276008855
# Epoch 226 | Validation DotSimilarity is 0.8474947620386776
# Epoch 226 | Train Loss 0.11366747027977409
#
# Epoch 227 | Test DotSimilarity is 0.8467009026138185
# Epoch 227 | Validation DotSimilarity is 0.8469287717469955
# Epoch 227 | Train Loss 0.11359209023179581
#
# Epoch 228 | Test DotSimilarity is 0.84622823161721
# Epoch 228 | Validation DotSimilarity is 0.8473886589520685
# Epoch 228 | Train Loss 0.11356366155171858
#
# Epoch 229 | Test DotSimilarity is 0.8463848817247847
# Epoch 229 | Validation DotSimilarity is 0.8471213064676447
# Epoch 229 | Train Loss 0.11348086516098202
#
# Epoch 230 | Test DotSimilarity is 0.846967356866737
# Epoch 230 | Validation DotSimilarity is 0.8478006478956287
# Epoch 230 | Train Loss 0.11344303894348429
#
# Epoch 231 | Test DotSimilarity is 0.8468459268102786
# Epoch 231 | Validation DotSimilarity is 0.8476440593747051
# Epoch 231 | Train Loss 0.11333108941515956
#
# Epoch 232 | Test DotSimilarity is 0.8470452886848918
# Epoch 232 | Validation DotSimilarity is 0.8476032648852182
# Epoch 232 | Train Loss 0.11342610112622854
#
# Epoch 233 | Test DotSimilarity is 0.8469019358651698
# Epoch 233 | Validation DotSimilarity is 0.8475271536497719
# Epoch 233 | Train Loss 0.11332525531908287
#
# Epoch 234 | Test DotSimilarity is 0.8467293875675524
# Epoch 234 | Validation DotSimilarity is 0.8475291040125678
# Epoch 234 | Train Loss 0.11317190469517961
#
# Epoch 235 | Test DotSimilarity is 0.847081360958306
# Epoch 235 | Validation DotSimilarity is 0.848291184087018
# Epoch 235 | Train Loss 0.11309591813582516
#
# Epoch 236 | Test DotSimilarity is 0.8464120790104874
# Epoch 236 | Validation DotSimilarity is 0.8468815777838885
# Epoch 236 | Train Loss 0.11306127172701376
#
# Epoch 237 | Test DotSimilarity is 0.8466759368008657
# Epoch 237 | Validation DotSimilarity is 0.8470244327290233
# Epoch 237 | Train Loss 0.11300003613293835
#
# Epoch 238 | Test DotSimilarity is 0.8461953465217376
# Epoch 238 | Validation DotSimilarity is 0.847478388391547
# Epoch 238 | Train Loss 0.11292998638708472
#
# Epoch 239 | Test DotSimilarity is 0.846972164081565
# Epoch 239 | Validation DotSimilarity is 0.846993378824351
# Epoch 239 | Train Loss 0.11287446987832042
#
# Epoch 240 | Test DotSimilarity is 0.846645839702207
# Epoch 240 | Validation DotSimilarity is 0.8472146854646311
# Epoch 240 | Train Loss 0.11283522554042001
#
# Epoch 241 | Test DotSimilarity is 0.846296277169974
# Epoch 241 | Validation DotSimilarity is 0.8471746661308883
# Epoch 241 | Train Loss 0.11282240758674955
#
# Epoch 242 | Test DotSimilarity is 0.846807351418086
# Epoch 242 | Validation DotSimilarity is 0.8474402574009889
# Epoch 242 | Train Loss 0.11273304562319117
#
# Epoch 243 | Test DotSimilarity is 0.8469246115702914
# Epoch 243 | Validation DotSimilarity is 0.8475875242082098
# Epoch 243 | Train Loss 0.11267990498656726
#
# Epoch 244 | Test DotSimilarity is 0.8463580539032306
# Epoch 244 | Validation DotSimilarity is 0.8473429250788064
# Epoch 244 | Train Loss 0.11262926369321498
#
# Epoch 245 | Test DotSimilarity is 0.8465273236459723
# Epoch 245 | Validation DotSimilarity is 0.8471725743397696
# Epoch 245 | Train Loss 0.11257804645640644
#
# Epoch 246 | Test DotSimilarity is 0.8466651156303459
# Epoch 246 | Validation DotSimilarity is 0.8474602861628159
# Epoch 246 | Train Loss 0.11245220797781054
#
# Epoch 247 | Test DotSimilarity is 0.8466832486553781
# Epoch 247 | Validation DotSimilarity is 0.8474329009112221
# Epoch 247 | Train Loss 0.11237021041349612
#
# Epoch 248 | Test DotSimilarity is 0.8467109037461372
# Epoch 248 | Validation DotSimilarity is 0.847642283909782
# Epoch 248 | Train Loss 0.11238912162521589
#
# Epoch 249 | Test DotSimilarity is 0.8470292437906832
# Epoch 249 | Validation DotSimilarity is 0.8477806192555981
# Epoch 249 | Train Loss 0.11232748259785703
#
# Epoch 250 | Test DotSimilarity is 0.8472664349048354
# Epoch 250 | Validation DotSimilarity is 0.8469557954296324
# Epoch 250 | Train Loss 0.11229469694873397
#
# Epoch 251 | Test DotSimilarity is 0.8463771046520258
# Epoch 251 | Validation DotSimilarity is 0.8476120865821385
# Epoch 251 | Train Loss 0.11220785748549884
#
# Epoch 252 | Test DotSimilarity is 0.8461189323872208
# Epoch 252 | Validation DotSimilarity is 0.847582706957058
# Epoch 252 | Train Loss 0.11215033681443078
#
# Epoch 253 | Test DotSimilarity is 0.8468749322323128
# Epoch 253 | Validation DotSimilarity is 0.8478185728419747
# Epoch 253 | Train Loss 0.11208532982801835
#
# Epoch 254 | Test DotSimilarity is 0.8465293278371959
# Epoch 254 | Validation DotSimilarity is 0.8477298304197446
# Epoch 254 | Train Loss 0.11209120408436955
#
# Epoch 255 | Test DotSimilarity is 0.8468402808995992
# Epoch 255 | Validation DotSimilarity is 0.8473431759461939
# Epoch 255 | Train Loss 0.1120319658565191
#
# Epoch 256 | Test DotSimilarity is 0.8469335711506825
# Epoch 256 | Validation DotSimilarity is 0.8472863140224574
# Epoch 256 | Train Loss 0.11203009237577398
#
# Epoch 257 | Test DotSimilarity is 0.8468574607396219
# Epoch 257 | Validation DotSimilarity is 0.847562492178045
# Epoch 257 | Train Loss 0.11190163061646688
#
# Epoch 258 | Test DotSimilarity is 0.8468087761668941
# Epoch 258 | Validation DotSimilarity is 0.8474348737988127
# Epoch 258 | Train Loss 0.11183798895114558
#
# Epoch 259 | Test DotSimilarity is 0.8464926869115876
# Epoch 259 | Validation DotSimilarity is 0.847855790158741
# Epoch 259 | Train Loss 0.11182136652845502
#
# Epoch 260 | Test DotSimilarity is 0.8464912361471947
# Epoch 260 | Validation DotSimilarity is 0.847612445559074
# Epoch 260 | Train Loss 0.11178779272795114
#
# Epoch 261 | Test DotSimilarity is 0.8462753080745531
# Epoch 261 | Validation DotSimilarity is 0.8473383404287642
# Epoch 261 | Train Loss 0.11176533907270948
#
# Epoch 262 | Test DotSimilarity is 0.8466938953886717
# Epoch 262 | Validation DotSimilarity is 0.847321126913344
# Epoch 262 | Train Loss 0.11164144428341709
#
# Epoch 263 | Test DotSimilarity is 0.84638495473193
# Epoch 263 | Validation DotSimilarity is 0.8469470417267821
# Epoch 263 | Train Loss 0.11158345545563159
#
# Epoch 264 | Test DotSimilarity is 0.8468430610332071
# Epoch 264 | Validation DotSimilarity is 0.8481609260184739
# Epoch 264 | Train Loss 0.11155814748317595
#
# Epoch 265 | Test DotSimilarity is 0.8468671935516455
# Epoch 265 | Validation DotSimilarity is 0.8477348398701293
# Epoch 265 | Train Loss 0.11150823678563482
#
# Epoch 266 | Test DotSimilarity is 0.8466839338079902
# Epoch 266 | Validation DotSimilarity is 0.8474916486340971
# Epoch 266 | Train Loss 0.11149526382466013
#
# Epoch 267 | Test DotSimilarity is 0.8467378671877326
# Epoch 267 | Validation DotSimilarity is 0.8475704346226266
# Epoch 267 | Train Loss 0.11146341004040017
#
# Epoch 268 | Test DotSimilarity is 0.8466472135176005
# Epoch 268 | Validation DotSimilarity is 0.8479805589929607
# Epoch 268 | Train Loss 0.11139888060990395
#
# Epoch 269 | Test DotSimilarity is 0.8461777076314587
# Epoch 269 | Validation DotSimilarity is 0.8476511748344674
# Epoch 269 | Train Loss 0.1113536507509682
#
# Epoch 270 | Test DotSimilarity is 0.8466980332897017
# Epoch 270 | Validation DotSimilarity is 0.847668286808992
# Epoch 270 | Train Loss 0.1112572061830497
#
# Epoch 271 | Test DotSimilarity is 0.8468058814050273
# Epoch 271 | Validation DotSimilarity is 0.8476445026220888
# Epoch 271 | Train Loss 0.11127363897208978
#
# Epoch 272 | Test DotSimilarity is 0.84728140444454
# Epoch 272 | Validation DotSimilarity is 0.8476107932711883
# Epoch 272 | Train Loss 0.11116446952426519
#
# Epoch 273 | Test DotSimilarity is 0.846748605322551
# Epoch 273 | Validation DotSimilarity is 0.8477968602046225
# Epoch 273 | Train Loss 0.11108898755676895
#
# Epoch 274 | Test DotSimilarity is 0.8473654257790356
# Epoch 274 | Validation DotSimilarity is 0.8475970907619932
# Epoch 274 | Train Loss 0.11108783373847206
#
# Epoch 275 | Test DotSimilarity is 0.846835650114996
# Epoch 275 | Validation DotSimilarity is 0.8477098839279068
# Epoch 275 | Train Loss 0.11104006028743198
#
# Epoch 276 | Test DotSimilarity is 0.8472110480700236
# Epoch 276 | Validation DotSimilarity is 0.8479676420400676
# Epoch 276 | Train Loss 0.11097412913959223
#
# Epoch 277 | Test DotSimilarity is 0.8469449275539249
# Epoch 277 | Validation DotSimilarity is 0.8480577935559042
# Epoch 277 | Train Loss 0.11094615163052883
#
# Epoch 278 | Test DotSimilarity is 0.846670543438942
# Epoch 278 | Validation DotSimilarity is 0.84775445414227
# Epoch 278 | Train Loss 0.11085148471991593
#
# Epoch 279 | Test DotSimilarity is 0.8463321243202612
# Epoch 279 | Validation DotSimilarity is 0.8473679380490047
# Epoch 279 | Train Loss 0.11078688108384065
#
# Epoch 280 | Test DotSimilarity is 0.8459719323446566
# Epoch 280 | Validation DotSimilarity is 0.8478887087225827
# Epoch 280 | Train Loss 0.11077244765751716
#
# Epoch 281 | Test DotSimilarity is 0.8464837185335807
# Epoch 281 | Validation DotSimilarity is 0.8473461358463963
# Epoch 281 | Train Loss 0.11074030963323253
#
# Epoch 282 | Test DotSimilarity is 0.8466813905424079
# Epoch 282 | Validation DotSimilarity is 0.8477143158171215
# Epoch 282 | Train Loss 0.11065273735934894
#
# Epoch 283 | Test DotSimilarity is 0.8470166374740334
# Epoch 283 | Validation DotSimilarity is 0.8478384691527318
# Epoch 283 | Train Loss 0.11070408793887412
#
# Epoch 284 | Test DotSimilarity is 0.8469631395048631
# Epoch 284 | Validation DotSimilarity is 0.847745099625187
# Epoch 284 | Train Loss 0.1106042750841405
#
# Epoch 285 | Test DotSimilarity is 0.8470669337561303
# Epoch 285 | Validation DotSimilarity is 0.8480064926851665
# Epoch 285 | Train Loss 0.11057207353089019
#
# Epoch 286 | Test DotSimilarity is 0.847084644352675
# Epoch 286 | Validation DotSimilarity is 0.8482873087995467
# Epoch 286 | Train Loss 0.11051541713128626
#
# Epoch 287 | Test DotSimilarity is 0.8472324501043822
# Epoch 287 | Validation DotSimilarity is 0.8470652101208085
# Epoch 287 | Train Loss 0.11051650203553359
#
# Epoch 288 | Test DotSimilarity is 0.8469712224300685
# Epoch 288 | Validation DotSimilarity is 0.8472321526926438
# Epoch 288 | Train Loss 0.1103973588660075
#
# Epoch 289 | Test DotSimilarity is 0.8469670752542828
# Epoch 289 | Validation DotSimilarity is 0.8471783829800188
# Epoch 289 | Train Loss 0.11036693016762546
#
# Epoch 290 | Test DotSimilarity is 0.8467989702085961
# Epoch 290 | Validation DotSimilarity is 0.8474355677467366
# Epoch 290 | Train Loss 0.11037217934649154
#
# Epoch 291 | Test DotSimilarity is 0.8467146975297343
# Epoch 291 | Validation DotSimilarity is 0.8472428707719027
# Epoch 291 | Train Loss 0.11025357104239157
#
# Epoch 292 | Test DotSimilarity is 0.8463884853507679
# Epoch 292 | Validation DotSimilarity is 0.8480058536047201
# Epoch 292 | Train Loss 0.11024169121209786
#
# Epoch 293 | Test DotSimilarity is 0.8470184767586441
# Epoch 293 | Validation DotSimilarity is 0.8477855202660041
# Epoch 293 | Train Loss 0.11019854192174958
#
# Epoch 294 | Test DotSimilarity is 0.8469331325446178
# Epoch 294 | Validation DotSimilarity is 0.8473221471143101
# Epoch 294 | Train Loss 0.11014867762723828
#
# Epoch 295 | Test DotSimilarity is 0.846464296953991
# Epoch 295 | Validation DotSimilarity is 0.8473929185039333
# Epoch 295 | Train Loss 0.11012703157142442
#
# Epoch 296 | Test DotSimilarity is 0.8467043592935761
# Epoch 296 | Validation DotSimilarity is 0.8479517217448512
# Epoch 296 | Train Loss 0.11002829600189445
#
# Epoch 297 | Test DotSimilarity is 0.8468094983077291
# Epoch 297 | Validation DotSimilarity is 0.8479962419703301
# Epoch 297 | Train Loss 0.11012361932017457
#
# Epoch 298 | Test DotSimilarity is 0.8474205768400966
# Epoch 298 | Validation DotSimilarity is 0.8480130124530784
# Epoch 298 | Train Loss 0.11000929402865246
#
# Epoch 299 | Test DotSimilarity is 0.847153030030034
# Epoch 299 | Validation DotSimilarity is 0.8481424450977687
# Epoch 299 | Train Loss 0.10889842753454901

# %%
from google.colab import runtime
runtime.unassign()
