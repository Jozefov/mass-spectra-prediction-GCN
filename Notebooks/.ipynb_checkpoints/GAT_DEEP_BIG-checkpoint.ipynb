# %%
# !pip install matchms
# !pip install rdkit
# !pip install torch_geometric
# !pip install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting matchms
#   Downloading matchms-0.18.0-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.6/109.6 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from matchms) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from matchms) (1.10.1)
# Requirement already satisfied: numba>=0.47 in /usr/local/lib/python3.10/dist-packages (from matchms) (0.56.4)
# Collecting deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from matchms) (1.22.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from matchms) (4.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from matchms) (4.65.0)
# Collecting pyteomics>=4.2
#   Downloading pyteomics-4.6-py2.py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.1/235.1 kB 29.9 MB/s eta 0:00:00
# Collecting sparsestack>=0.4.1
#   Downloading sparsestack-0.4.1-py3-none-any.whl (10 kB)
# Collecting pickydict>=0.4.0
#   Downloading pickydict-0.4.0-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from matchms) (3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from matchms) (2.27.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.47->matchms) (67.7.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.47->matchms) (0.39.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->matchms) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matchms) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matchms) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matchms) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matchms) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matchms) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matchms) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matchms) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->matchms) (23.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->matchms) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->matchms) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->matchms) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->matchms) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->matchms) (1.16.0)
# Installing collected packages: pyteomics, pickydict, deprecated, sparsestack, matchms
# Successfully installed deprecated-1.2.13 matchms-0.18.0 pickydict-0.4.0 pyteomics-4.6 sparsestack-0.4.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rdkit
#   Downloading rdkit-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 21.5 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (8.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.22.4)
# Installing collected packages: rdkit
# Successfully installed rdkit-2022.9.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch_geometric
#   Downloading torch_geometric-2.3.1.tar.gz (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.6/661.6 kB 43.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2.27.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.0.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.22.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (4.65.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch_geometric) (2.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (1.26.15)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (3.1.0)
# Building wheels for collected packages: torch_geometric
#   Building wheel for torch_geometric (pyproject.toml) ... done
#   Created wheel for torch_geometric: filename=torch_geometric-2.3.1-py3-none-any.whl size=910476 sha256=37fa3d84e8de67ba34491ba38a3af4e839dc8407d8c41370a73ff716b71caa1a
#   Stored in directory: /root/.cache/pip/wheels/ac/dc/30/e2874821ff308ee67dcd7a66dbde912411e19e35a1addda028
# Successfully built torch_geometric
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.3.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pickle5
#   Downloading pickle5-0.0.11.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 13.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pickle5
#   Building wheel for pickle5 (setup.py) ... done
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp310-cp310-linux_x86_64.whl size=256403 sha256=c114654df14aad337f4afb24c3671de6a862a3a78ff77918ef0476a233e62e33
#   Stored in directory: /root/.cache/pip/wheels/7d/14/ef/4aab19d27fa8e58772be5c71c16add0426acf9e1f64353235c
# Successfully built pickle5
# Installing collected packages: pickle5
# Successfully installed pickle5-0.0.11

# %%
from matchms.importing import load_from_msp
import numpy as np
import os
import random
import pickle
from rdkit import Chem
from rdkit.Chem import Descriptors
import matchms
from matchms import Spectrum

import matplotlib.pyplot as plt
import warnings

from rdkit.Chem.rdmolops import GetAdjacencyMatrix

# Pytorch and Pytorch Geometric
import torch
from torch_geometric.data import Data

from torch.nn import Linear
import torch.nn.functional as F 
from torch_geometric.nn import GCNConv, TopKPooling, global_mean_pool, GATConv
from torch_geometric.nn import global_mean_pool as gap, global_max_pool as gmp
import torch.nn as nn
from torch_geometric.data import DataLoader
from torch.optim.lr_scheduler import StepLR

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir("/content/drive/MyDrive/NIST_SMALL")
BASE_DIRECTORY = "/content/drive/MyDrive/NIST_SMALL"

TEST_DATA_SIZE = 5000
OUTPUT_SIZE = 1000
INTENSITY_POWER = 0.5

# %% [markdown]
# The code is commented on to avoid unintentional rewriting of the created dataset.

# %%
with open("/content/drive/MyDrive/NIST_SMALL/Preprocessed_test_pow_preparation_no_sparse_small.output", 'rb') as handle:
    data_list_test  = pickle.load(handle)

# with open("/content/drive/MyDrive/NIST_SMALL/Preprocessed_train_pow_preparation_no_sparse_small.output", 'rb') as handle:
#    data_list_train  = pickle.load(handle)

# %%
NUMBER_OF_VALIDATION = 5000
# shuffled_indices = np.random.permutation(len(data_list_train))
# train_indices = shuffled_indices[NUMBER_OF_VALIDATION:]
# val_indices = shuffled_indices[:NUMBER_OF_VALIDATION]

test_dataset = data_list_test[:NUMBER_OF_VALIDATION]

# validation_dataset = torch.utils.data.Subset(data_list_train, val_indices)
# train_dataset = torch.utils.data.Subset(data_list_train, train_indices)

# %%
with open("/content/drive/MyDrive/NIST_SMALL/train_subset_pow.pkl", 'rb') as handle:
    train_dataset  = pickle.load(handle)

with open("/content/drive/MyDrive/NIST_SMALL/validation_subset_pow.pkl", 'rb') as handle:
    validation_dataset  = pickle.load(handle)

# %%
len(validation_dataset), len(train_dataset)
# Out:
# (5000, 107709)

# %%
EMBEDDING_SIZE = 2000
NODE_FEATURES = 50
MASS_SHIFT = 5 
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def mask_prediction_by_mass(total_mass, raw_prediction, index_shift):
    # Zero out predictions to the right of the maximum possible mass.
    # input 
    # anchor_indices: shape (,batch_size) = ex [3,4,5]
    #     total_mass = Weights of whole molecule, not only fragment
    # data: shape (batch_size, embedding), embedding from GNN in our case
    # index_shift: int constant how far can heaviest fragment differ from weight of original molecule
    # 

    data = raw_prediction.type(torch.float64)
    
    total_mass = torch.round(total_mass).type(torch.int64)
    indices = torch.arange(data.shape[-1])[None, ...].to(device)

    right_of_total_mass = indices > (
            total_mass[..., None] +
            index_shift)
    return torch.where(right_of_total_mass, torch.zeros_like(data),
                        data)

# %%
def scatter_by_anchor_indices(anchor_indices, data, index_shift):
    # reverse vector by anchor_indices and rest set to zero
    # input 
    # anchor_indices: shape (,batch_size) = ex [3,4,5]
    #     total_mass = Weights of whole molecule, not only fragment
    # data: shape (batch_size, embedding), embedding from GNN in our case
    # index_shift: int constant how far can heaviest fragment differ from weight of original molecule
    
    index_shift = index_shift
    anchor_indices = anchor_indices
    data = data.type(torch.float64)
    batch_size = data.shape[0]
    
    num_data_columns = data.shape[-1]
    indices = torch.arange(num_data_columns)[None, ...].to(device)
    shifted_indices = anchor_indices[..., None] - indices + index_shift
    valid_indices = shifted_indices >= 0

   

    batch_indices = torch.tile(
          torch.arange(batch_size)[..., None], [1, num_data_columns]).to(device)
    shifted_indices += batch_indices * num_data_columns

    shifted_indices = torch.reshape(shifted_indices, [-1])
    num_elements = data.shape[0] * data.shape[1]
    row_indices = torch.arange(num_elements).to(device)
    stacked_indices = torch.stack([row_indices, shifted_indices], axis=1)


    lower_batch_boundaries = torch.reshape(batch_indices * num_data_columns, [-1])
    upper_batch_boundaries = torch.reshape(((batch_indices + 1) * num_data_columns),
                                          [-1])

    valid_indices = torch.logical_and(shifted_indices >= lower_batch_boundaries,
                                     shifted_indices < upper_batch_boundaries)

    stacked_indices = stacked_indices[valid_indices]

    dense_shape = torch.tile(torch.tensor(num_elements)[..., None], [2]).type(torch.int32)

    scattering_matrix = torch.sparse.FloatTensor(stacked_indices.type(torch.int64).T,
                                                 torch.ones_like(stacked_indices[:, 0]).type(torch.float64),
                                                dense_shape.tolist())

    flattened_data = torch.reshape(data, [-1])[..., None]
    flattened_output = torch.sparse.mm(scattering_matrix, flattened_data)
    return torch.reshape(torch.transpose(flattened_output, 0, 1), [-1, num_data_columns])

# %%
def reverse_prediction(total_mass, raw_prediction, index_shift):
    # reverse vector by anchor_indices and rest set to zero and make preproessing
    # input 
    # total_mass: shape (,batch_size) = ex [3,4,5]
    #     total_mass = Weights of whole molecule, not only fragment
    # raw_prediction: shape (batch_size, embedding), embedding from GNN in our case
    # index_shift: int constant how far can heaviest fragment differ from weight of original molecule
    #     total_mass = feature_dict[fmap_constants.MOLECULE_WEIGHT][..., 0]
    
    total_mass = torch.round(total_mass).type(torch.int32)
    return scatter_by_anchor_indices(
        total_mass, raw_prediction, index_shift)

# %%
def dot_product(true, pred, mass_pow=3, intensity_pow=0.6):
    # shape for true and pred is one dimensional array
    # pred (number_of_predicted_bins)
    # defaul value for mass_pow and intensity_pow is set for Stein dot product
    assert true.ndim == pred.ndim and true.ndim == 1
    length = true.shape[-1]
    mass = np.arange(length).astype(np.float64)
        
    wl = mass ** mass_pow * pred**intensity_pow
    wu = mass ** mass_pow * true**intensity_pow
    
    pred_weighted_norm = np.sqrt(np.sum((wl**2)))
    true_weighted_norm = np.sqrt(np.sum((wu**2)))
    
    result = np.sum(wl*wu) / (pred_weighted_norm * true_weighted_norm)
    
    return result

# %%
def validate_similarities(true, pred, mass_pow, intensity_pow):
    # Helper function for validation
    similarities = np.array([])
    for true_instance, pred_instance in zip(true, pred):
        tmp = dot_product(true_instance, pred_instance, mass_pow=mass_pow, intensity_pow=intensity_pow)
        
        similarities = np.concatenate((similarities, tmp), axis=None)
    return similarities

# %%
class SKIPblock(nn.Module):
    def __init__(self, in_features, hidden_features, bottleneck_factor=0.5, USE_dropout=True, dropout_rate = 0.2):
        super().__init__()
        #only need to change shape of the residual if num_channels changes (i.e. in_c != out_c)
        #[bs,in_c,seq_length]->conv(1,in_c,out_c)->[bs,out_c,seq_length]
        
        self.batchNorm1 = nn.BatchNorm1d(in_features)
        self.relu1 = nn.ReLU()
        if USE_dropout:
            self.dropout1 = nn.Dropout(dropout_rate)
        self.hidden1= nn.utils.weight_norm(nn.Linear(in_features, int(hidden_features * bottleneck_factor)),name='weight',dim=0)
        
        self.batchNorm2 = nn.BatchNorm1d(int(hidden_features * bottleneck_factor))
        self.relu2 = nn.ReLU()
        if USE_dropout:
            self.dropout2 = nn.Dropout(dropout_rate)
        self.hidden2 = nn.utils.weight_norm(nn.Linear(int(hidden_features * bottleneck_factor), in_features),name='weight',dim=0)



    def forward(self, x):
        
        hidden = self.batchNorm1(x)
        hidden = self.relu1(hidden)
        hidden = self.dropout1(hidden)
        hidden = self.hidden1(hidden)

        hidden = self.batchNorm2(hidden)
        hidden = self.relu2(hidden)
        hidden = self.dropout2(hidden)
        hidden = self.hidden2(hidden)

        hidden = hidden + x

        return hidden

# %%
class SKIPGAT(nn.Module):
    def __init__(self, in_features, hidden_features, heads, USE_dropout=True, dropout_rate = 0.1):
        super().__init__()
        #[bs,in_c,seq_length]->conv(1,in_c,out_c)->[bs,out_c,seq_length]

        self.relu1 = nn.ReLU()
        if USE_dropout:
            self.conv1 = GATConv(in_features, hidden_features, heads=heads, dropout=dropout_rate)
        else:
            self.conv1 = GATConv(in_features, hidden_features, heads=heads)
        
        self.relu2 = nn.ReLU()
        if USE_dropout:
            self.conv2 = GATConv(hidden_features*heads, int(in_features/heads), heads=heads, dropout=dropout_rate)
        else:
            self.conv2 = GATConv(hidden_features*heads, int(in_features/heads), heads=heads)

    def forward(self, x, edge_index, edge_weight):
        
        hidden = self.relu1(x)
        hidden = self.conv1(hidden, edge_index, edge_weight)
        
        hidden = self.relu2(hidden)
        hidden = self.conv2(hidden, edge_index, edge_weight)
        hidden = hidden + x
        
        return hidden

# %%
class GAT_DEEP_BIG(torch.nn.Module):
    def __init__(self, heads):
        # Init parent
        super(GAT_DEEP_BIG, self).__init__()
        torch.manual_seed(42)
        
        EMBEDDING_SIZE_REDUCED = int(EMBEDDING_SIZE*0.15)
        # GCN layers
        self.initial_conv = GATConv(NODE_FEATURES, EMBEDDING_SIZE_REDUCED, heads=heads)
        self.skipgat1 = SKIPGAT(EMBEDDING_SIZE_REDUCED*heads, EMBEDDING_SIZE_REDUCED, heads=heads)
        self.skipgat2 = SKIPGAT(EMBEDDING_SIZE_REDUCED*heads, EMBEDDING_SIZE_REDUCED, heads=heads)
        self.skipgat3 = SKIPGAT(EMBEDDING_SIZE_REDUCED*heads, EMBEDDING_SIZE_REDUCED, heads=heads)
        self.skipgat4 = SKIPGAT(EMBEDDING_SIZE_REDUCED*heads, EMBEDDING_SIZE_REDUCED, heads=heads)
        self.mean_conv = GATConv(EMBEDDING_SIZE_REDUCED*heads, EMBEDDING_SIZE_REDUCED, heads=heads, concat=False)
        self.mean_relu = nn.ReLU()

        self.bottleneck = Linear(EMBEDDING_SIZE_REDUCED, EMBEDDING_SIZE)

        self.skip1 = SKIPblock(EMBEDDING_SIZE, EMBEDDING_SIZE)
        self.skip2 = SKIPblock(EMBEDDING_SIZE, EMBEDDING_SIZE)
        self.skip3 = SKIPblock(EMBEDDING_SIZE, EMBEDDING_SIZE)
        self.skip4 = SKIPblock(EMBEDDING_SIZE, EMBEDDING_SIZE)
        self.skip5 = SKIPblock(EMBEDDING_SIZE, EMBEDDING_SIZE)
        self.skip6 = SKIPblock(EMBEDDING_SIZE, EMBEDDING_SIZE)
        self.skip7 = SKIPblock(EMBEDDING_SIZE, EMBEDDING_SIZE)
        self.relu_out_resnet = nn.ReLU()

        self.forward_prediction = Linear(EMBEDDING_SIZE, OUTPUT_SIZE)
        self.backward_prediction = Linear(EMBEDDING_SIZE, OUTPUT_SIZE)
        self.gate = Linear(EMBEDDING_SIZE, OUTPUT_SIZE)

        self.relu_out = nn.ReLU()


    def forward(self, x, edge_index, edge_weight, total_mass, batch_index):
        
        hidden = self.initial_conv(x, edge_index, edge_weight)
     
        # Other Conv layers
        hidden = self.skipgat1(hidden, edge_index, edge_weight)
        hidden = self.skipgat2(hidden, edge_index, edge_weight)
        hidden = self.skipgat3(hidden, edge_index, edge_weight)
        hidden = self.skipgat4(hidden, edge_index, edge_weight)
        hidden = self.mean_conv(hidden, edge_index, edge_weight)
        

        hidden = gmp(hidden, batch_index)
        hidden = self.bottleneck(hidden)

        hidden = self.skip1(hidden)
        hidden = self.skip2(hidden)
        hidden = self.skip3(hidden)
        hidden = self.skip4(hidden)
        hidden = self.skip5(hidden)
        hidden = self.skip6(hidden)
        hidden = self.skip7(hidden)
        
        hidden = self.relu_out_resnet(hidden)

        # Bidirectional layer
        # Forward prediction
        forward_prediction_hidden = self.forward_prediction(hidden)
        forward_prediction_hidden = mask_prediction_by_mass(total_mass, forward_prediction_hidden, MASS_SHIFT)
        
        # # Backward prediction
        backward_prediction_hidden = self.backward_prediction(hidden)
        backward_prediction_hidden = reverse_prediction(total_mass, backward_prediction_hidden, MASS_SHIFT)
        
        # # Gate
        gate_hidden = self.gate(hidden)
        gate_hidden = F.sigmoid(gate_hidden)

        # # Apply a final (linear) classifier.
        out = gate_hidden * forward_prediction_hidden + (1. - gate_hidden) * backward_prediction_hidden
        out = self.relu_out(out)
        
        out = out.type(torch.float64)
        return out

heads = 4
model = GAT_DEEP_BIG(heads)
MODEL_NAME = "GAT_DEEP_BIG_POW"
MODEL_SAVE = os.path.join(BASE_DIRECTORY, MODEL_NAME)
os.makedirs(MODEL_SAVE, mode=0o777, exist_ok=True)
print(model)
print("Number of parameters: ", sum(p.numel() for p in model.parameters()))
# Out:
# GAT_DEEP_BIG(
#   (initial_conv): GATConv(50, 300, heads=4)
#   (skipgat1): SKIPGAT(
#     (relu1): ReLU()
#     (conv1): GATConv(1200, 300, heads=4)
#     (relu2): ReLU()
#     (conv2): GATConv(1200, 300, heads=4)
#   )
#   (skipgat2): SKIPGAT(
#     (relu1): ReLU()
#     (conv1): GATConv(1200, 300, heads=4)
#     (relu2): ReLU()
#     (conv2): GATConv(1200, 300, heads=4)
#   )
#   (skipgat3): SKIPGAT(
#     (relu1): ReLU()
#     (conv1): GATConv(1200, 300, heads=4)
#     (relu2): ReLU()
#     (conv2): GATConv(1200, 300, heads=4)
#   )
#   (skipgat4): SKIPGAT(
#     (relu1): ReLU()
#     (conv1): GATConv(1200, 300, heads=4)
#     (relu2): ReLU()
#     (conv2): GATConv(1200, 300, heads=4)
#   )
#   (mean_conv): GATConv(1200, 300, heads=4)
#   (mean_relu): ReLU()
#   (bottleneck): Linear(in_features=300, out_features=2000, bias=True)
#   (skip1): SKIPblock(
#     (batchNorm1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (hidden1): Linear(in_features=2000, out_features=1000, bias=True)
#     (batchNorm2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (hidden2): Linear(in_features=1000, out_features=2000, bias=True)
#   )
#   (skip2): SKIPblock(
#     (batchNorm1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (hidden1): Linear(in_features=2000, out_features=1000, bias=True)
#     (batchNorm2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (hidden2): Linear(in_features=1000, out_features=2000, bias=True)
#   )
#   (skip3): SKIPblock(
#     (batchNorm1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (hidden1): Linear(in_features=2000, out_features=1000, bias=True)
#     (batchNorm2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (hidden2): Linear(in_features=1000, out_features=2000, bias=True)
#   )
#   (skip4): SKIPblock(
#     (batchNorm1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (hidden1): Linear(in_features=2000, out_features=1000, bias=True)
#     (batchNorm2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (hidden2): Linear(in_features=1000, out_features=2000, bias=True)
#   )
#   (skip5): SKIPblock(
#     (batchNorm1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (hidden1): Linear(in_features=2000, out_features=1000, bias=True)
#     (batchNorm2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (hidden2): Linear(in_features=1000, out_features=2000, bias=True)
#   )
#   (skip6): SKIPblock(
#     (batchNorm1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (hidden1): Linear(in_features=2000, out_features=1000, bias=True)
#     (batchNorm2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (hidden2): Linear(in_features=1000, out_features=2000, bias=True)
#   )
#   (skip7): SKIPblock(
#     (batchNorm1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#     (hidden1): Linear(in_features=2000, out_features=1000, bias=True)
#     (batchNorm2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.2, inplace=False)
#     (hidden2): Linear(in_features=1000, out_features=2000, bias=True)
#   )
#   (relu_out_resnet): ReLU()
#   (forward_prediction): Linear(in_features=2000, out_features=1000, bias=True)
#   (backward_prediction): Linear(in_features=2000, out_features=1000, bias=True)
#   (gate): Linear(in_features=2000, out_features=1000, bias=True)
#   (relu_out): ReLU()
# )
# Number of parameters:  47744100

# %%
import warnings
warnings.filterwarnings("ignore")

######################################
#  LOSS
######################################

# Root mean squared error
loss_fn = torch.nn.HuberLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0005)  
scheduler = StepLR(optimizer, step_size=100, gamma=0.5)

# Use GPU for training

model = model.to(device)

# Wrap data in a data loader

NUM_GRAPHS_PER_BATCH = 64


loader = DataLoader(train_dataset, 
                    batch_size=NUM_GRAPHS_PER_BATCH, shuffle=True)

validation_loader = DataLoader(validation_dataset, 
                    batch_size=NUM_GRAPHS_PER_BATCH, shuffle=True)

test_loader = DataLoader(test_dataset, 
                         batch_size=NUM_GRAPHS_PER_BATCH, shuffle=True)
SAVE_EVERY_X_EPOCH = 10
REPORT_EVERY_X_EPOCH = 1

def train(loader):
    # Enumerate over the data
    loss_per_batch = np.array([])
    for batch in loader:
        # Use GPU
        batch.to(device)  
        # Reset gradients
        optimizer.zero_grad() 
        # Passing the node features and the connection info
        pred = model(batch.x.float(), batch.edge_index, batch.edge_attr, batch.molecular_weight, batch.batch) 
        # Calculating the loss and gradients
        loss = loss_fn(pred, batch.y)
        loss.backward()  
        # Update using the gradients
        optimizer.step()
        loss_per_batch = np.concatenate((loss_per_batch, np.array([loss.clone().detach().cpu().numpy()])))
    return loss_per_batch

print("Starting training...")

for epoch in range(300):
    scheduler.step()
    loss = train(loader)
    pred_test_similarity = np.array([])
    pred_validation_similarity = np.array([])
   
   
    if epoch % REPORT_EVERY_X_EPOCH == 0:
        for batch in test_loader:
            batch.to(device)  
            pred = model(batch.x.float(), batch.edge_index, batch.edge_attr, batch.molecular_weight, batch.batch)

            batch_similarity = validate_similarities(batch.y.detach().cpu().numpy(),
                                  pred.detach().cpu().numpy(),
                                  mass_pow=1.0, intensity_pow=0.5)

            pred_test_similarity = np.concatenate((pred_test_similarity, batch_similarity))
    
        for batch in validation_loader:
           
            batch.to(device)  
            pred = model(batch.x.float(), batch.edge_index, batch.edge_attr, batch.molecular_weight, batch.batch)

            batch_similarity = validate_similarities(batch.y.detach().cpu().numpy(),
                                  pred.detach().cpu().numpy(),
                                  mass_pow=1.0, intensity_pow=0.5)

            pred_validation_similarity = np.concatenate((pred_validation_similarity, batch_similarity))
            
        
        print(f"Epoch {epoch} | Test DotSimilarity is {pred_test_similarity.mean()}")
        print(f"Epoch {epoch} | Validation DotSimilarity is {pred_validation_similarity.mean()}")
        print(f"Epoch {epoch} | Train Loss {loss.mean()}")
        print()

    
    if epoch % SAVE_EVERY_X_EPOCH == 0:
        SAVE_PATH = f"{epoch}.pt"
            
        # Save model
        torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': loss,
        'metadata': {"loss" : "HuberLoss",
                     "Dataset": "Preprocessed_test_pow_preparation_no_sparse_small",
                     "test_similarities": pred_test_similarity.mean()}
        }, os.path.join(MODEL_SAVE, SAVE_PATH))

        LOSS_FILE = f"all_loss_until_{epoch}.output"
        with open(os.path.join(MODEL_SAVE, LOSS_FILE), 'wb') as fid:
            pickle.dump(loss.mean(), fid)
            fid.close()
# Out:
# Starting training...
# Epoch 0 | Test DotSimilarity is 0.7671715655764678
# Epoch 0 | Validation DotSimilarity is 0.7669089568656259
# Epoch 0 | Train Loss 0.28949637052893756
#
# Epoch 1 | Test DotSimilarity is 0.7940990872968743
# Epoch 1 | Validation DotSimilarity is 0.7931576303535846
# Epoch 1 | Train Loss 0.25967389813520236
#
# Epoch 2 | Test DotSimilarity is 0.8057834050518559
# Epoch 2 | Validation DotSimilarity is 0.806302602412955
# Epoch 2 | Train Loss 0.24518939381030344
#
# Epoch 3 | Test DotSimilarity is 0.8144638713190734
# Epoch 3 | Validation DotSimilarity is 0.8146799555580183
# Epoch 3 | Train Loss 0.2357080446066941
#
# Epoch 4 | Test DotSimilarity is 0.8210044464041791
# Epoch 4 | Validation DotSimilarity is 0.820518782108933
# Epoch 4 | Train Loss 0.22855068357360553
#
# Epoch 5 | Test DotSimilarity is 0.8258175579778619
# Epoch 5 | Validation DotSimilarity is 0.825476791579347
# Epoch 5 | Train Loss 0.22208265049871337
#
# Epoch 6 | Test DotSimilarity is 0.8282809933967845
# Epoch 6 | Validation DotSimilarity is 0.8283073046868158
# Epoch 6 | Train Loss 0.21649533874742555
#
# Epoch 7 | Test DotSimilarity is 0.8313594781300563
# Epoch 7 | Validation DotSimilarity is 0.8317806154121193
# Epoch 7 | Train Loss 0.2114604859479259
#
# Epoch 8 | Test DotSimilarity is 0.8349278432488343
# Epoch 8 | Validation DotSimilarity is 0.8342538148626403
# Epoch 8 | Train Loss 0.20693801652970623
#
# Epoch 9 | Test DotSimilarity is 0.8371404195647829
# Epoch 9 | Validation DotSimilarity is 0.836391953188985
# Epoch 9 | Train Loss 0.20256658230092783
#
# Epoch 10 | Test DotSimilarity is 0.8382698262125414
# Epoch 10 | Validation DotSimilarity is 0.8383878504149587
# Epoch 10 | Train Loss 0.19844042564080025
#
# Epoch 11 | Test DotSimilarity is 0.8407772817893354
# Epoch 11 | Validation DotSimilarity is 0.8399836177494473
# Epoch 11 | Train Loss 0.19466767123719575
#
# Epoch 12 | Test DotSimilarity is 0.8426035622222197
# Epoch 12 | Validation DotSimilarity is 0.8420281629534496
# Epoch 12 | Train Loss 0.191199238622451
#
# Epoch 13 | Test DotSimilarity is 0.8428530542720367
# Epoch 13 | Validation DotSimilarity is 0.8432832793393163
# Epoch 13 | Train Loss 0.18788128702825124
#
# Epoch 14 | Test DotSimilarity is 0.8444425727334605
# Epoch 14 | Validation DotSimilarity is 0.8440238067043018
# Epoch 14 | Train Loss 0.18492785640548454
#
# Epoch 15 | Test DotSimilarity is 0.8441086653716413
# Epoch 15 | Validation DotSimilarity is 0.8450851903689912
# Epoch 15 | Train Loss 0.18189048379127074
#
# Epoch 16 | Test DotSimilarity is 0.8464529948043786
# Epoch 16 | Validation DotSimilarity is 0.8462602530050052
# Epoch 16 | Train Loss 0.1792837273430556
#
# Epoch 17 | Test DotSimilarity is 0.8449072152926634
# Epoch 17 | Validation DotSimilarity is 0.8462519913429358
# Epoch 17 | Train Loss 0.17659822003861217
#
# Epoch 18 | Test DotSimilarity is 0.8470057875598206
# Epoch 18 | Validation DotSimilarity is 0.8464942632513633
# Epoch 18 | Train Loss 0.1742283607516467
#
# Epoch 19 | Test DotSimilarity is 0.8464203547342893
# Epoch 19 | Validation DotSimilarity is 0.8470722993093288
# Epoch 19 | Train Loss 0.17193734647151762
#
# Epoch 20 | Test DotSimilarity is 0.8482529184221709
# Epoch 20 | Validation DotSimilarity is 0.849187522987988
# Epoch 20 | Train Loss 0.16982697261183663
#
# Epoch 21 | Test DotSimilarity is 0.848252273305109
# Epoch 21 | Validation DotSimilarity is 0.8493171251868141
# Epoch 21 | Train Loss 0.16775727637804178
#
# Epoch 22 | Test DotSimilarity is 0.8484476862921503
# Epoch 22 | Validation DotSimilarity is 0.8486630096218932
# Epoch 22 | Train Loss 0.16582934434080057
#
# Epoch 23 | Test DotSimilarity is 0.8479339487868659
# Epoch 23 | Validation DotSimilarity is 0.8480739228635932
# Epoch 23 | Train Loss 0.16391905513549387
#
# Epoch 24 | Test DotSimilarity is 0.8489120504888277
# Epoch 24 | Validation DotSimilarity is 0.8491395245603458
# Epoch 24 | Train Loss 0.1621419596924323
#
# Epoch 25 | Test DotSimilarity is 0.8483108227837
# Epoch 25 | Validation DotSimilarity is 0.8489004183186298
# Epoch 25 | Train Loss 0.16063486330111665
#
# Epoch 26 | Test DotSimilarity is 0.8482514173887834
# Epoch 26 | Validation DotSimilarity is 0.8489434911819371
# Epoch 26 | Train Loss 0.1590384653002818
#
# Epoch 27 | Test DotSimilarity is 0.8505110833334005
# Epoch 27 | Validation DotSimilarity is 0.8501921340460816
# Epoch 27 | Train Loss 0.1574739727950043
#
# Epoch 28 | Test DotSimilarity is 0.8493752615697382
# Epoch 28 | Validation DotSimilarity is 0.8495341644822018
# Epoch 28 | Train Loss 0.1560278462400414
#
# Epoch 29 | Test DotSimilarity is 0.8508106983986646
# Epoch 29 | Validation DotSimilarity is 0.85083035647285
# Epoch 29 | Train Loss 0.1547756060392879
#
# Epoch 30 | Test DotSimilarity is 0.8495451218565729
# Epoch 30 | Validation DotSimilarity is 0.8493321611909651
# Epoch 30 | Train Loss 0.15340474721580555
#
# Epoch 31 | Test DotSimilarity is 0.8507370852701722
# Epoch 31 | Validation DotSimilarity is 0.8513653740847258
# Epoch 31 | Train Loss 0.15209309742736646
#
# Epoch 32 | Test DotSimilarity is 0.8508816730835191
# Epoch 32 | Validation DotSimilarity is 0.8510443150919662
# Epoch 32 | Train Loss 0.15091854386421366
#
# Epoch 33 | Test DotSimilarity is 0.850797266138317
# Epoch 33 | Validation DotSimilarity is 0.8510796057992768
# Epoch 33 | Train Loss 0.14975766213196448
#
# Epoch 34 | Test DotSimilarity is 0.8509024412092957
# Epoch 34 | Validation DotSimilarity is 0.8511877241950173
# Epoch 34 | Train Loss 0.14870912700095287
#
# Epoch 35 | Test DotSimilarity is 0.8505760226577866
# Epoch 35 | Validation DotSimilarity is 0.8505652235050798
# Epoch 35 | Train Loss 0.14758584184518406
#
# Epoch 36 | Test DotSimilarity is 0.8515416213956534
# Epoch 36 | Validation DotSimilarity is 0.8513946653124261
# Epoch 36 | Train Loss 0.14649160535712538
#
# Epoch 37 | Test DotSimilarity is 0.8518733380357913
# Epoch 37 | Validation DotSimilarity is 0.8516224849735716
# Epoch 37 | Train Loss 0.1455423516201289
#
# Epoch 38 | Test DotSimilarity is 0.8512399643975205
# Epoch 38 | Validation DotSimilarity is 0.8515921335124734
# Epoch 38 | Train Loss 0.14472702653763
#
# Epoch 39 | Test DotSimilarity is 0.8517655949617517
# Epoch 39 | Validation DotSimilarity is 0.8518993991846923
# Epoch 39 | Train Loss 0.1436785207427067
#
# Epoch 40 | Test DotSimilarity is 0.8514956236255095
# Epoch 40 | Validation DotSimilarity is 0.851501073474856
# Epoch 40 | Train Loss 0.14281201745572067
#
# Epoch 41 | Test DotSimilarity is 0.8517440419753372
# Epoch 41 | Validation DotSimilarity is 0.8525128819991059
# Epoch 41 | Train Loss 0.14200038863698514
#
# Epoch 42 | Test DotSimilarity is 0.8517203454288232
# Epoch 42 | Validation DotSimilarity is 0.8525143998261862
# Epoch 42 | Train Loss 0.14108327803547765
#
# Epoch 43 | Test DotSimilarity is 0.8523990780024644
# Epoch 43 | Validation DotSimilarity is 0.8525459341579604
# Epoch 43 | Train Loss 0.1402677143908457
#
# Epoch 44 | Test DotSimilarity is 0.8512637079387949
# Epoch 44 | Validation DotSimilarity is 0.8514683978920621
# Epoch 44 | Train Loss 0.13948840333252843
#
# Epoch 45 | Test DotSimilarity is 0.8519029722725485
# Epoch 45 | Validation DotSimilarity is 0.8519103008021602
# Epoch 45 | Train Loss 0.13875745766971384
#
# Epoch 46 | Test DotSimilarity is 0.8520768158298954
# Epoch 46 | Validation DotSimilarity is 0.8514715504465865
# Epoch 46 | Train Loss 0.13798488111450605
#
# Epoch 47 | Test DotSimilarity is 0.8500190478431787
# Epoch 47 | Validation DotSimilarity is 0.8510006962846659
# Epoch 47 | Train Loss 0.1373970105050589
#
# Epoch 48 | Test DotSimilarity is 0.851989118096355
# Epoch 48 | Validation DotSimilarity is 0.8524203114752145
# Epoch 48 | Train Loss 0.1366302350780864
#
# Epoch 49 | Test DotSimilarity is 0.8519350377121712
# Epoch 49 | Validation DotSimilarity is 0.8524997689643622
# Epoch 49 | Train Loss 0.13595438974722462
#
# Epoch 50 | Test DotSimilarity is 0.85205787491429
# Epoch 50 | Validation DotSimilarity is 0.852885798274292
# Epoch 50 | Train Loss 0.13538606154479796
#
# Epoch 51 | Test DotSimilarity is 0.8522055239984933
# Epoch 51 | Validation DotSimilarity is 0.852555400785664
# Epoch 51 | Train Loss 0.13462990502545322
#
# Epoch 52 | Test DotSimilarity is 0.8530290341804717
# Epoch 52 | Validation DotSimilarity is 0.8532261943636542
# Epoch 52 | Train Loss 0.13404127171446817
#
# Epoch 53 | Test DotSimilarity is 0.8521187346946059
# Epoch 53 | Validation DotSimilarity is 0.8523354009369275
# Epoch 53 | Train Loss 0.13345461899041375
#
# Epoch 54 | Test DotSimilarity is 0.8515335017440013
# Epoch 54 | Validation DotSimilarity is 0.8520649485884962
# Epoch 54 | Train Loss 0.13293142340747444
#
# Epoch 55 | Test DotSimilarity is 0.8523057447710392
# Epoch 55 | Validation DotSimilarity is 0.8525220934040942
# Epoch 55 | Train Loss 0.13232806662675425
#
# Epoch 56 | Test DotSimilarity is 0.8525238913880611
# Epoch 56 | Validation DotSimilarity is 0.8528796442951654
# Epoch 56 | Train Loss 0.13188132757207902
#
# Epoch 57 | Test DotSimilarity is 0.8531096070872287
# Epoch 57 | Validation DotSimilarity is 0.8533735307063578
# Epoch 57 | Train Loss 0.1313050345658595
#
# Epoch 58 | Test DotSimilarity is 0.8526102955838422
# Epoch 58 | Validation DotSimilarity is 0.8526126844183116
# Epoch 58 | Train Loss 0.13076248012801206
#
# Epoch 59 | Test DotSimilarity is 0.8537343923860331
# Epoch 59 | Validation DotSimilarity is 0.8537864902167308
# Epoch 59 | Train Loss 0.13024416441434347
#
# Epoch 60 | Test DotSimilarity is 0.8526935087495593
# Epoch 60 | Validation DotSimilarity is 0.8528334976120027
# Epoch 60 | Train Loss 0.129836324453146
#
# Epoch 61 | Test DotSimilarity is 0.8533097257116379
# Epoch 61 | Validation DotSimilarity is 0.8541914595218714
# Epoch 61 | Train Loss 0.12912038235349738
#
# Epoch 62 | Test DotSimilarity is 0.8526060284192037
# Epoch 62 | Validation DotSimilarity is 0.8531618482273942
# Epoch 62 | Train Loss 0.12882325513905382
#
# Epoch 63 | Test DotSimilarity is 0.8532873853924582
# Epoch 63 | Validation DotSimilarity is 0.8521202482273695
# Epoch 63 | Train Loss 0.12838642740223916
#
# Epoch 64 | Test DotSimilarity is 0.8523723189064937
# Epoch 64 | Validation DotSimilarity is 0.8528471523198412
# Epoch 64 | Train Loss 0.1278165532403915
#
# Epoch 65 | Test DotSimilarity is 0.8533006894278691
# Epoch 65 | Validation DotSimilarity is 0.8535393169347999
# Epoch 65 | Train Loss 0.12749760648576658
#
# Epoch 66 | Test DotSimilarity is 0.8534494452928378
# Epoch 66 | Validation DotSimilarity is 0.8527212902408399
# Epoch 66 | Train Loss 0.12702221273246836
#
# Epoch 67 | Test DotSimilarity is 0.8535118555061119
# Epoch 67 | Validation DotSimilarity is 0.8540661476190929
# Epoch 67 | Train Loss 0.1265315001511492
#
# Epoch 68 | Test DotSimilarity is 0.8531193203251795
# Epoch 68 | Validation DotSimilarity is 0.8532092008808829
# Epoch 68 | Train Loss 0.12616397609451416
#
# Epoch 69 | Test DotSimilarity is 0.8519835941278978
# Epoch 69 | Validation DotSimilarity is 0.8532219123786302
# Epoch 69 | Train Loss 0.12576672549607165
#
# Epoch 70 | Test DotSimilarity is 0.8530092947899728
# Epoch 70 | Validation DotSimilarity is 0.8532874963242586
# Epoch 70 | Train Loss 0.1254530877861696
#
# Epoch 71 | Test DotSimilarity is 0.8533039032031665
# Epoch 71 | Validation DotSimilarity is 0.8531760500625327
# Epoch 71 | Train Loss 0.12495291388520455
#
# Epoch 72 | Test DotSimilarity is 0.8536179724173742
# Epoch 72 | Validation DotSimilarity is 0.8538589938510202
# Epoch 72 | Train Loss 0.12460750234343031
#
# Epoch 73 | Test DotSimilarity is 0.8532520056976586
# Epoch 73 | Validation DotSimilarity is 0.8535260168624245
# Epoch 73 | Train Loss 0.12417635040691412
#
# Epoch 74 | Test DotSimilarity is 0.8534472462687006
# Epoch 74 | Validation DotSimilarity is 0.8538611832933579
# Epoch 74 | Train Loss 0.12397845376197823
#
# Epoch 75 | Test DotSimilarity is 0.8541051019778115
# Epoch 75 | Validation DotSimilarity is 0.8543382016243403
# Epoch 75 | Train Loss 0.12353175101401223
#
# Epoch 76 | Test DotSimilarity is 0.8538230414309234
# Epoch 76 | Validation DotSimilarity is 0.8536775002182713
# Epoch 76 | Train Loss 0.12318311121049681
#
# Epoch 77 | Test DotSimilarity is 0.8521792195671718
# Epoch 77 | Validation DotSimilarity is 0.8526247777817163
# Epoch 77 | Train Loss 0.12285155307570172
#
# Epoch 78 | Test DotSimilarity is 0.8526518557714273
# Epoch 78 | Validation DotSimilarity is 0.8534871236973152
# Epoch 78 | Train Loss 0.12250555072818231
#
# Epoch 79 | Test DotSimilarity is 0.8537708207187176
# Epoch 79 | Validation DotSimilarity is 0.8539807008775692
# Epoch 79 | Train Loss 0.12210753385477947
#
# Epoch 80 | Test DotSimilarity is 0.8530129843310348
# Epoch 80 | Validation DotSimilarity is 0.8533405628451521
# Epoch 80 | Train Loss 0.12183939516678156
#
# Epoch 81 | Test DotSimilarity is 0.8535850050012445
# Epoch 81 | Validation DotSimilarity is 0.8534066310360932
# Epoch 81 | Train Loss 0.12144961846460318
#
# Epoch 82 | Test DotSimilarity is 0.8534453477602852
# Epoch 82 | Validation DotSimilarity is 0.8539314536086349
# Epoch 82 | Train Loss 0.12118609788548293
#
# Epoch 83 | Test DotSimilarity is 0.854101194233126
# Epoch 83 | Validation DotSimilarity is 0.8547070035148059
# Epoch 83 | Train Loss 0.12091095199356892
#
# Epoch 84 | Test DotSimilarity is 0.8528447803666688
# Epoch 84 | Validation DotSimilarity is 0.8533030032101946
# Epoch 84 | Train Loss 0.12062142774994591
#
# Epoch 85 | Test DotSimilarity is 0.8527552951278718
# Epoch 85 | Validation DotSimilarity is 0.8543852298055085
# Epoch 85 | Train Loss 0.12026585511220617
#
# Epoch 86 | Test DotSimilarity is 0.8530430491122566
# Epoch 86 | Validation DotSimilarity is 0.8534541756878203
# Epoch 86 | Train Loss 0.12005418148194204
#
# Epoch 87 | Test DotSimilarity is 0.8532339513610666
# Epoch 87 | Validation DotSimilarity is 0.8535473773204078
# Epoch 87 | Train Loss 0.11967787097798895
#
# Epoch 88 | Test DotSimilarity is 0.8541447422274454
# Epoch 88 | Validation DotSimilarity is 0.8544513798774378
# Epoch 88 | Train Loss 0.11947274884521496
#
# Epoch 89 | Test DotSimilarity is 0.853810554771838
# Epoch 89 | Validation DotSimilarity is 0.8536404989432893
# Epoch 89 | Train Loss 0.11918154390936123
#
# Epoch 90 | Test DotSimilarity is 0.8544661048320259
# Epoch 90 | Validation DotSimilarity is 0.8543057349007086
# Epoch 90 | Train Loss 0.11895346141280592
#
# Epoch 91 | Test DotSimilarity is 0.8540572395761908
# Epoch 91 | Validation DotSimilarity is 0.854328157525617
# Epoch 91 | Train Loss 0.11861190374896594
#
# Epoch 92 | Test DotSimilarity is 0.8538704611771469
# Epoch 92 | Validation DotSimilarity is 0.8538323961565742
# Epoch 92 | Train Loss 0.11837419492890157
#
# Epoch 93 | Test DotSimilarity is 0.8535597501969574
# Epoch 93 | Validation DotSimilarity is 0.85353116432502
# Epoch 93 | Train Loss 0.11805565568850128
#
# Epoch 94 | Test DotSimilarity is 0.8541857626781323
# Epoch 94 | Validation DotSimilarity is 0.8545651098836308
# Epoch 94 | Train Loss 0.1178672802751926
#
# Epoch 95 | Test DotSimilarity is 0.8535834711248576
# Epoch 95 | Validation DotSimilarity is 0.8535489632071074
# Epoch 95 | Train Loss 0.11777717130513447
#
# Epoch 96 | Test DotSimilarity is 0.8539699379008286
# Epoch 96 | Validation DotSimilarity is 0.8532755088553302
# Epoch 96 | Train Loss 0.11740385259105557
#
# Epoch 97 | Test DotSimilarity is 0.8538714395379394
# Epoch 97 | Validation DotSimilarity is 0.854533984089021
# Epoch 97 | Train Loss 0.11720026347906512
#
# Epoch 98 | Test DotSimilarity is 0.8539349002215003
# Epoch 98 | Validation DotSimilarity is 0.8539987306871816
# Epoch 98 | Train Loss 0.11686523977213721
#
# Epoch 99 | Test DotSimilarity is 0.8561367401718301
# Epoch 99 | Validation DotSimilarity is 0.856487082220567
# Epoch 99 | Train Loss 0.11046353158255749
#
# Epoch 100 | Test DotSimilarity is 0.8558822227638215
# Epoch 100 | Validation DotSimilarity is 0.8562319201533996
# Epoch 100 | Train Loss 0.10808441197156349
#
# Epoch 101 | Test DotSimilarity is 0.8555785529446351
# Epoch 101 | Validation DotSimilarity is 0.856556367028129
# Epoch 101 | Train Loss 0.10736317546096683
#
# Epoch 102 | Test DotSimilarity is 0.8559239145380696
# Epoch 102 | Validation DotSimilarity is 0.8566004792137318
# Epoch 102 | Train Loss 0.10679554188668725
#
# Epoch 103 | Test DotSimilarity is 0.8558108992663936
# Epoch 103 | Validation DotSimilarity is 0.8563359931933675
# Epoch 103 | Train Loss 0.10639015524774188
#
# Epoch 104 | Test DotSimilarity is 0.8559853519194043
# Epoch 104 | Validation DotSimilarity is 0.8557090309688812
# Epoch 104 | Train Loss 0.10610247365959648
#
# Epoch 105 | Test DotSimilarity is 0.856307354872558
# Epoch 105 | Validation DotSimilarity is 0.8565765949320661
# Epoch 105 | Train Loss 0.10570045999367607
#
# Epoch 106 | Test DotSimilarity is 0.855976825399371
# Epoch 106 | Validation DotSimilarity is 0.8563282517961103
# Epoch 106 | Train Loss 0.10539433576446983
#
# Epoch 107 | Test DotSimilarity is 0.8561636328344111
# Epoch 107 | Validation DotSimilarity is 0.8564797924700804
# Epoch 107 | Train Loss 0.10511410213311717
#
# Epoch 108 | Test DotSimilarity is 0.8566137093343472
# Epoch 108 | Validation DotSimilarity is 0.8565523518183301
# Epoch 108 | Train Loss 0.10491133001349942
#
# Epoch 109 | Test DotSimilarity is 0.8558865661062578
# Epoch 109 | Validation DotSimilarity is 0.8563959122017925
# Epoch 109 | Train Loss 0.10470967959576376
#
# Epoch 110 | Test DotSimilarity is 0.8559878645779998
# Epoch 110 | Validation DotSimilarity is 0.8562859537765353
# Epoch 110 | Train Loss 0.10444110771200123
#
# Epoch 111 | Test DotSimilarity is 0.855146121967518
# Epoch 111 | Validation DotSimilarity is 0.855962264405605
# Epoch 111 | Train Loss 0.10421941345299235
#
# Epoch 112 | Test DotSimilarity is 0.8558560600573646
# Epoch 112 | Validation DotSimilarity is 0.85640313654851
# Epoch 112 | Train Loss 0.10403238335772892
#
# Epoch 113 | Test DotSimilarity is 0.8561004686597742
# Epoch 113 | Validation DotSimilarity is 0.8562822911382314
# Epoch 113 | Train Loss 0.10383565447795376
#
# Epoch 114 | Test DotSimilarity is 0.8552406860921943
# Epoch 114 | Validation DotSimilarity is 0.8560670162314084
# Epoch 114 | Train Loss 0.10361509303145798
#
# Epoch 115 | Test DotSimilarity is 0.8557356821428309
# Epoch 115 | Validation DotSimilarity is 0.8558212359327001
# Epoch 115 | Train Loss 0.10343433824755385
#
# Epoch 116 | Test DotSimilarity is 0.8558214280306116
# Epoch 116 | Validation DotSimilarity is 0.8557077557777842
# Epoch 116 | Train Loss 0.10324989700520237
#
# Epoch 117 | Test DotSimilarity is 0.8557285154045807
# Epoch 117 | Validation DotSimilarity is 0.8565867100787365
# Epoch 117 | Train Loss 0.1030828481518667
#
# Epoch 118 | Test DotSimilarity is 0.8559357361263888
# Epoch 118 | Validation DotSimilarity is 0.8564106438869199
# Epoch 118 | Train Loss 0.1029089806982101
#
# Epoch 119 | Test DotSimilarity is 0.8554973372813581
# Epoch 119 | Validation DotSimilarity is 0.8556343977447836
# Epoch 119 | Train Loss 0.10273575358631626
#
# Epoch 120 | Test DotSimilarity is 0.855768811612816
# Epoch 120 | Validation DotSimilarity is 0.8555759340873892
# Epoch 120 | Train Loss 0.1025317734116772
#
# Epoch 121 | Test DotSimilarity is 0.8554636373215074
# Epoch 121 | Validation DotSimilarity is 0.8556978959486347
# Epoch 121 | Train Loss 0.10238787187747576
#
# Epoch 122 | Test DotSimilarity is 0.8559098981738018
# Epoch 122 | Validation DotSimilarity is 0.8563215693488079
# Epoch 122 | Train Loss 0.1022080786302128
#
# Epoch 123 | Test DotSimilarity is 0.8561085347452385
# Epoch 123 | Validation DotSimilarity is 0.8562003250636077
# Epoch 123 | Train Loss 0.10213785410383966
#
# Epoch 124 | Test DotSimilarity is 0.855320480271483
# Epoch 124 | Validation DotSimilarity is 0.8560462621953767
# Epoch 124 | Train Loss 0.10195555931486958
#
# Epoch 125 | Test DotSimilarity is 0.8556077668880755
# Epoch 125 | Validation DotSimilarity is 0.8559382580351664
# Epoch 125 | Train Loss 0.10174702832286951
#
# Epoch 126 | Test DotSimilarity is 0.8561975938598154
# Epoch 126 | Validation DotSimilarity is 0.8561336078136713
# Epoch 126 | Train Loss 0.1015976062601956
#
# Epoch 127 | Test DotSimilarity is 0.8557158249596296
# Epoch 127 | Validation DotSimilarity is 0.8560551733046173
# Epoch 127 | Train Loss 0.10151333945922858
#
# Epoch 128 | Test DotSimilarity is 0.8555271719501787
# Epoch 128 | Validation DotSimilarity is 0.8559574856636045
# Epoch 128 | Train Loss 0.1013411755048114
#
# Epoch 129 | Test DotSimilarity is 0.8558278610769988
# Epoch 129 | Validation DotSimilarity is 0.8561180420785038
# Epoch 129 | Train Loss 0.10117417390962674
#
# Epoch 130 | Test DotSimilarity is 0.8556068539363603
# Epoch 130 | Validation DotSimilarity is 0.8554665250845724
# Epoch 130 | Train Loss 0.10105650340541442
#
# Epoch 131 | Test DotSimilarity is 0.8558499588697003
# Epoch 131 | Validation DotSimilarity is 0.8562677219060548
# Epoch 131 | Train Loss 0.1009136992113666
#
# Epoch 132 | Test DotSimilarity is 0.8554974245049328
# Epoch 132 | Validation DotSimilarity is 0.8560330854277985
# Epoch 132 | Train Loss 0.1007885094551963
#
# Epoch 133 | Test DotSimilarity is 0.855610738991508
# Epoch 133 | Validation DotSimilarity is 0.8559715501197838
# Epoch 133 | Train Loss 0.10061190776145117
#
# Epoch 134 | Test DotSimilarity is 0.8552297600455641
# Epoch 134 | Validation DotSimilarity is 0.8559146447209399
# Epoch 134 | Train Loss 0.10054214130480013
#
# Epoch 135 | Test DotSimilarity is 0.8558684484226579
# Epoch 135 | Validation DotSimilarity is 0.8556920396759884
# Epoch 135 | Train Loss 0.1004208718935725
#
# Epoch 136 | Test DotSimilarity is 0.8552372361239908
# Epoch 136 | Validation DotSimilarity is 0.8560072496613015
# Epoch 136 | Train Loss 0.10031524624950723
#
# Epoch 137 | Test DotSimilarity is 0.8551634541809708
# Epoch 137 | Validation DotSimilarity is 0.8558648411189832
# Epoch 137 | Train Loss 0.10015987634081348
#
# Epoch 138 | Test DotSimilarity is 0.8556026225069041
# Epoch 138 | Validation DotSimilarity is 0.855688065827937
# Epoch 138 | Train Loss 0.10004924002420054
#
# Epoch 139 | Test DotSimilarity is 0.85555735429954
# Epoch 139 | Validation DotSimilarity is 0.8555514867852402
# Epoch 139 | Train Loss 0.09991805521010658
#
# Epoch 140 | Test DotSimilarity is 0.8560552177799328
# Epoch 140 | Validation DotSimilarity is 0.8560000321107922
# Epoch 140 | Train Loss 0.09981655029666789
#
# Epoch 141 | Test DotSimilarity is 0.8563144636917421
# Epoch 141 | Validation DotSimilarity is 0.8568497740648969
# Epoch 141 | Train Loss 0.09965256917786368
#
# Epoch 142 | Test DotSimilarity is 0.8549548815127402
# Epoch 142 | Validation DotSimilarity is 0.855912755842346
# Epoch 142 | Train Loss 0.09949313578695718
#
# Epoch 143 | Test DotSimilarity is 0.8560987132368632
# Epoch 143 | Validation DotSimilarity is 0.8560339465156734
# Epoch 143 | Train Loss 0.0994484742506316
#
# Epoch 144 | Test DotSimilarity is 0.8554706196645395
# Epoch 144 | Validation DotSimilarity is 0.8557838977367078
# Epoch 144 | Train Loss 0.09933106725491152
#
# Epoch 145 | Test DotSimilarity is 0.8555031870048638
# Epoch 145 | Validation DotSimilarity is 0.8559692383769427
# Epoch 145 | Train Loss 0.09922005979438199
#
# Epoch 146 | Test DotSimilarity is 0.8561268970550587
# Epoch 146 | Validation DotSimilarity is 0.8561257074818026
# Epoch 146 | Train Loss 0.099095455478625
#
# Epoch 147 | Test DotSimilarity is 0.855462087168741
# Epoch 147 | Validation DotSimilarity is 0.8554250680304769
# Epoch 147 | Train Loss 0.09893015567009662
#
# Epoch 148 | Test DotSimilarity is 0.8556724917873278
# Epoch 148 | Validation DotSimilarity is 0.8556373378237185
# Epoch 148 | Train Loss 0.09886675993053304
#
# Epoch 149 | Test DotSimilarity is 0.8550879904029535
# Epoch 149 | Validation DotSimilarity is 0.8553366643098045
# Epoch 149 | Train Loss 0.09876008173834186
#
# Epoch 150 | Test DotSimilarity is 0.8553655917704964
# Epoch 150 | Validation DotSimilarity is 0.8556512470309051
# Epoch 150 | Train Loss 0.09867632270940589
#
# Epoch 151 | Test DotSimilarity is 0.8556891370104273
# Epoch 151 | Validation DotSimilarity is 0.8559090633239655
# Epoch 151 | Train Loss 0.0985584097614981
#
# Epoch 152 | Test DotSimilarity is 0.8553778466806401
# Epoch 152 | Validation DotSimilarity is 0.8554706708602642
# Epoch 152 | Train Loss 0.09843351488931677
#
# Epoch 153 | Test DotSimilarity is 0.8558266173660583
# Epoch 153 | Validation DotSimilarity is 0.8561312255000441
# Epoch 153 | Train Loss 0.09834873220876017
#
# Epoch 154 | Test DotSimilarity is 0.8555287553148111
# Epoch 154 | Validation DotSimilarity is 0.8562435778316135
# Epoch 154 | Train Loss 0.09824821638244166
#
# Epoch 155 | Test DotSimilarity is 0.8558612675147007
# Epoch 155 | Validation DotSimilarity is 0.8557527227492603
# Epoch 155 | Train Loss 0.09812877469538135
#
# Epoch 156 | Test DotSimilarity is 0.8557960258379127
# Epoch 156 | Validation DotSimilarity is 0.8565118452490919
# Epoch 156 | Train Loss 0.09800660894134898
#
# Epoch 157 | Test DotSimilarity is 0.8549349795582873
# Epoch 157 | Validation DotSimilarity is 0.854692169068797
# Epoch 157 | Train Loss 0.09790969450488482
#
# Epoch 158 | Test DotSimilarity is 0.8559617215341059
# Epoch 158 | Validation DotSimilarity is 0.8561845304727976
# Epoch 158 | Train Loss 0.09781481686396239
#
# Epoch 159 | Test DotSimilarity is 0.8550978198476292
# Epoch 159 | Validation DotSimilarity is 0.8555292794945635
# Epoch 159 | Train Loss 0.09767625114823462
#
# Epoch 160 | Test DotSimilarity is 0.855509654164637
# Epoch 160 | Validation DotSimilarity is 0.8558491488448875
# Epoch 160 | Train Loss 0.09762797753108733
#
# Epoch 161 | Test DotSimilarity is 0.8558119551620587
# Epoch 161 | Validation DotSimilarity is 0.855929980971351
# Epoch 161 | Train Loss 0.09745983261535049
#
# Epoch 162 | Test DotSimilarity is 0.8556057320850657
# Epoch 162 | Validation DotSimilarity is 0.8555016330449274
# Epoch 162 | Train Loss 0.0974464079544006
#
# Epoch 163 | Test DotSimilarity is 0.8557675774055394
# Epoch 163 | Validation DotSimilarity is 0.8557750353582749
# Epoch 163 | Train Loss 0.09728446679094055
#
# Epoch 164 | Test DotSimilarity is 0.8555787465939783
# Epoch 164 | Validation DotSimilarity is 0.855729890872322
# Epoch 164 | Train Loss 0.09726624989629737
#
# Epoch 165 | Test DotSimilarity is 0.8554768487977071
# Epoch 165 | Validation DotSimilarity is 0.8558624616487103
# Epoch 165 | Train Loss 0.09714042601177601
#
# Epoch 166 | Test DotSimilarity is 0.8558025900314882
# Epoch 166 | Validation DotSimilarity is 0.8558847052309131
# Epoch 166 | Train Loss 0.0970032345201756
#
# Epoch 167 | Test DotSimilarity is 0.8558145784097307
# Epoch 167 | Validation DotSimilarity is 0.8556119960148306
# Epoch 167 | Train Loss 0.09689668011976124
#
# Epoch 168 | Test DotSimilarity is 0.8554255238142358
# Epoch 168 | Validation DotSimilarity is 0.8558732752198557
# Epoch 168 | Train Loss 0.09690961551517634
#
# Epoch 169 | Test DotSimilarity is 0.8555661794707865
# Epoch 169 | Validation DotSimilarity is 0.8562082396934567
# Epoch 169 | Train Loss 0.09679728850959178
#
# Epoch 170 | Test DotSimilarity is 0.8554612142162792
# Epoch 170 | Validation DotSimilarity is 0.8555692511770078
# Epoch 170 | Train Loss 0.09666231849191718
#
# Epoch 171 | Test DotSimilarity is 0.8557795569486134
# Epoch 171 | Validation DotSimilarity is 0.8558047283436062
# Epoch 171 | Train Loss 0.09659071021629802
#
# Epoch 172 | Test DotSimilarity is 0.8552652752941445
# Epoch 172 | Validation DotSimilarity is 0.8548947422150617
# Epoch 172 | Train Loss 0.09643774341847787
#
# Epoch 173 | Test DotSimilarity is 0.8553084197206797
# Epoch 173 | Validation DotSimilarity is 0.8562299318253795
# Epoch 173 | Train Loss 0.09636083836498563
#
# Epoch 174 | Test DotSimilarity is 0.8552898275234753
# Epoch 174 | Validation DotSimilarity is 0.8558103309935252
# Epoch 174 | Train Loss 0.09632219272096186
#
# Epoch 175 | Test DotSimilarity is 0.8556985390908066
# Epoch 175 | Validation DotSimilarity is 0.8557085437340345
# Epoch 175 | Train Loss 0.09615769820935509
#
# Epoch 176 | Test DotSimilarity is 0.8551465311190656
# Epoch 176 | Validation DotSimilarity is 0.8554026954768222
# Epoch 176 | Train Loss 0.09612294450345235
#
# Epoch 177 | Test DotSimilarity is 0.8552032768217701
# Epoch 177 | Validation DotSimilarity is 0.855534298151316
# Epoch 177 | Train Loss 0.09607519179555417
#
# Epoch 178 | Test DotSimilarity is 0.8554348981980174
# Epoch 178 | Validation DotSimilarity is 0.8557131180870876
# Epoch 178 | Train Loss 0.09596131196530307
#
# Epoch 179 | Test DotSimilarity is 0.855722280661956
# Epoch 179 | Validation DotSimilarity is 0.8558981594972022
# Epoch 179 | Train Loss 0.0959035316248525
#
# Epoch 180 | Test DotSimilarity is 0.8559316607612887
# Epoch 180 | Validation DotSimilarity is 0.8555235299334883
# Epoch 180 | Train Loss 0.09581414318275137
#
# Epoch 181 | Test DotSimilarity is 0.8555993474194522
# Epoch 181 | Validation DotSimilarity is 0.8557676511489284
# Epoch 181 | Train Loss 0.09577723414940899
#
# Epoch 182 | Test DotSimilarity is 0.8554688889874505
# Epoch 182 | Validation DotSimilarity is 0.8552329926210951
# Epoch 182 | Train Loss 0.0956879954903371
#
# Epoch 183 | Test DotSimilarity is 0.8553056219540125
# Epoch 183 | Validation DotSimilarity is 0.856154155791361
# Epoch 183 | Train Loss 0.09558289690019765
#
# Epoch 184 | Test DotSimilarity is 0.8548478341820166
# Epoch 184 | Validation DotSimilarity is 0.8555622234162885
# Epoch 184 | Train Loss 0.095465522239586
#
# Epoch 185 | Test DotSimilarity is 0.8554194567776038
# Epoch 185 | Validation DotSimilarity is 0.8560284521317695
# Epoch 185 | Train Loss 0.09545288360099273
#
# Epoch 186 | Test DotSimilarity is 0.8552589529234962
# Epoch 186 | Validation DotSimilarity is 0.8554068157164196
# Epoch 186 | Train Loss 0.09536991000967307
#
# Epoch 187 | Test DotSimilarity is 0.8552317565956855
# Epoch 187 | Validation DotSimilarity is 0.8561993796672026
# Epoch 187 | Train Loss 0.09528246936609241
#
# Epoch 188 | Test DotSimilarity is 0.8549294592515069
# Epoch 188 | Validation DotSimilarity is 0.8551061033563601
# Epoch 188 | Train Loss 0.09523444252029274
#
# Epoch 189 | Test DotSimilarity is 0.8550443550646208
# Epoch 189 | Validation DotSimilarity is 0.8557494987196591
# Epoch 189 | Train Loss 0.09511649340013809
#
# Epoch 190 | Test DotSimilarity is 0.8549681985025319
# Epoch 190 | Validation DotSimilarity is 0.8554457999582579
# Epoch 190 | Train Loss 0.09500948034037221
#
# Epoch 191 | Test DotSimilarity is 0.8548199249180136
# Epoch 191 | Validation DotSimilarity is 0.8560962309778726
# Epoch 191 | Train Loss 0.09490232082656457
#
# Epoch 192 | Test DotSimilarity is 0.855287335243126
# Epoch 192 | Validation DotSimilarity is 0.8563374552413603
# Epoch 192 | Train Loss 0.0949113760317032
#
# Epoch 193 | Test DotSimilarity is 0.8547266564861402
# Epoch 193 | Validation DotSimilarity is 0.8555765545906022
# Epoch 193 | Train Loss 0.09482797051148853
#
# Epoch 194 | Test DotSimilarity is 0.855530677497129
# Epoch 194 | Validation DotSimilarity is 0.8559983236616052
# Epoch 194 | Train Loss 0.09466567842242855
#
# Epoch 195 | Test DotSimilarity is 0.8556416371127481
# Epoch 195 | Validation DotSimilarity is 0.856333447146121
# Epoch 195 | Train Loss 0.09464533535238549
#
# Epoch 196 | Test DotSimilarity is 0.8552023193654964
# Epoch 196 | Validation DotSimilarity is 0.8561487387419924
# Epoch 196 | Train Loss 0.09456843585481017
#
# Epoch 197 | Test DotSimilarity is 0.8547956905189152
# Epoch 197 | Validation DotSimilarity is 0.8552957012036709
# Epoch 197 | Train Loss 0.0944855921462661
#
# Epoch 198 | Test DotSimilarity is 0.8547886609809365
# Epoch 198 | Validation DotSimilarity is 0.855895141940346
# Epoch 198 | Train Loss 0.09440043031361527
#
# Epoch 199 | Test DotSimilarity is 0.8555786287993443
# Epoch 199 | Validation DotSimilarity is 0.8564673996646605
# Epoch 199 | Train Loss 0.09155144733709764
#
# Epoch 200 | Test DotSimilarity is 0.855849780197603
# Epoch 200 | Validation DotSimilarity is 0.8568808851150146
# Epoch 200 | Train Loss 0.09049874415919379
#
# Epoch 201 | Test DotSimilarity is 0.8558662205008702
# Epoch 201 | Validation DotSimilarity is 0.8571752782014007
# Epoch 201 | Train Loss 0.09010009779333361
#
# Epoch 202 | Test DotSimilarity is 0.8559124065132699
# Epoch 202 | Validation DotSimilarity is 0.856958312092672
# Epoch 202 | Train Loss 0.08989926158697088
#
# Epoch 203 | Test DotSimilarity is 0.8557874780236645
# Epoch 203 | Validation DotSimilarity is 0.8562330377775347
# Epoch 203 | Train Loss 0.089754612460917
#
# Epoch 204 | Test DotSimilarity is 0.8561889782407841
# Epoch 204 | Validation DotSimilarity is 0.8567909578274244
# Epoch 204 | Train Loss 0.08964785031639341
#
# Epoch 205 | Test DotSimilarity is 0.855625604276991
# Epoch 205 | Validation DotSimilarity is 0.8569177471542702
# Epoch 205 | Train Loss 0.08943636169790314
#
# Epoch 206 | Test DotSimilarity is 0.8563658934627312
# Epoch 206 | Validation DotSimilarity is 0.8567519788861616
# Epoch 206 | Train Loss 0.08941127925658623
#
# Epoch 207 | Test DotSimilarity is 0.8557121324857034
# Epoch 207 | Validation DotSimilarity is 0.856288962105336
# Epoch 207 | Train Loss 0.08927279374440772
#
# Epoch 208 | Test DotSimilarity is 0.8557905535749
# Epoch 208 | Validation DotSimilarity is 0.8559375364512384
# Epoch 208 | Train Loss 0.08916482935541639
#
# Epoch 209 | Test DotSimilarity is 0.8557237317700681
# Epoch 209 | Validation DotSimilarity is 0.856612068992232
# Epoch 209 | Train Loss 0.08906275690718919
#
# Epoch 210 | Test DotSimilarity is 0.8553391951194386
# Epoch 210 | Validation DotSimilarity is 0.85638791452679
# Epoch 210 | Train Loss 0.0889907475179355
#
# Epoch 211 | Test DotSimilarity is 0.8560891033113011
# Epoch 211 | Validation DotSimilarity is 0.8570344403957839
# Epoch 211 | Train Loss 0.08895560206651919
#
# Epoch 212 | Test DotSimilarity is 0.85609275767793
# Epoch 212 | Validation DotSimilarity is 0.8562627545496322
# Epoch 212 | Train Loss 0.0888546957641068
#
# Epoch 213 | Test DotSimilarity is 0.8557758361602334
# Epoch 213 | Validation DotSimilarity is 0.8561786649137463
# Epoch 213 | Train Loss 0.08880150818231264
#
# Epoch 214 | Test DotSimilarity is 0.8558660209499027
# Epoch 214 | Validation DotSimilarity is 0.8565557252755911
# Epoch 214 | Train Loss 0.08868803368019391
#
# Epoch 215 | Test DotSimilarity is 0.8558817881335402
# Epoch 215 | Validation DotSimilarity is 0.8565198722298668
# Epoch 215 | Train Loss 0.08868660773364087
#
# Epoch 216 | Test DotSimilarity is 0.855650783099547
# Epoch 216 | Validation DotSimilarity is 0.8564395842003032
# Epoch 216 | Train Loss 0.08856769861596293
#
# Epoch 217 | Test DotSimilarity is 0.855555873270164
# Epoch 217 | Validation DotSimilarity is 0.8559624645956224
# Epoch 217 | Train Loss 0.08853517570974237
#
# Epoch 218 | Test DotSimilarity is 0.8553529650517412
# Epoch 218 | Validation DotSimilarity is 0.8561342960217234
# Epoch 218 | Train Loss 0.08843744068535252
#
# Epoch 219 | Test DotSimilarity is 0.8553616936921873
# Epoch 219 | Validation DotSimilarity is 0.8561940838481114
# Epoch 219 | Train Loss 0.08840712661074664
#
# Epoch 220 | Test DotSimilarity is 0.8556409120897848
# Epoch 220 | Validation DotSimilarity is 0.8560853124324107
# Epoch 220 | Train Loss 0.08832994438133443
#
# Epoch 221 | Test DotSimilarity is 0.8558372948397344
# Epoch 221 | Validation DotSimilarity is 0.8566483392895093
# Epoch 221 | Train Loss 0.08827777399119326
#
# Epoch 222 | Test DotSimilarity is 0.8558792925635742
# Epoch 222 | Validation DotSimilarity is 0.8567282827683542
# Epoch 222 | Train Loss 0.08823031939391926
#
# Epoch 223 | Test DotSimilarity is 0.8557442781208443
# Epoch 223 | Validation DotSimilarity is 0.8560237719064073
# Epoch 223 | Train Loss 0.08818338810340531
#
# Epoch 224 | Test DotSimilarity is 0.8559098263256696
# Epoch 224 | Validation DotSimilarity is 0.8565411805032264
# Epoch 224 | Train Loss 0.08809805414559582
#
# Epoch 225 | Test DotSimilarity is 0.8558312776357154
# Epoch 225 | Validation DotSimilarity is 0.8568916984276899
# Epoch 225 | Train Loss 0.08808115964437185
#
# Epoch 226 | Test DotSimilarity is 0.8554965268214059
# Epoch 226 | Validation DotSimilarity is 0.8561479031940015
# Epoch 226 | Train Loss 0.08799112930452059
#
# Epoch 227 | Test DotSimilarity is 0.855662690561752
# Epoch 227 | Validation DotSimilarity is 0.8561186158618842
# Epoch 227 | Train Loss 0.08791844007887653
#
# Epoch 228 | Test DotSimilarity is 0.855543605970972
# Epoch 228 | Validation DotSimilarity is 0.8561138954768903
# Epoch 228 | Train Loss 0.08789631001368037
#
# Epoch 229 | Test DotSimilarity is 0.8554484789087994
# Epoch 229 | Validation DotSimilarity is 0.8562255961992787
# Epoch 229 | Train Loss 0.08786944486798395
#
# Epoch 230 | Test DotSimilarity is 0.8555607291127175
# Epoch 230 | Validation DotSimilarity is 0.8562981767278965
# Epoch 230 | Train Loss 0.08781317026081899
#
# Epoch 231 | Test DotSimilarity is 0.8558785593536493
# Epoch 231 | Validation DotSimilarity is 0.8562997903619054
# Epoch 231 | Train Loss 0.08776248845258773
#
# Epoch 232 | Test DotSimilarity is 0.8558976280184208
# Epoch 232 | Validation DotSimilarity is 0.8558441759147339
# Epoch 232 | Train Loss 0.08768717710042301
#
# Epoch 233 | Test DotSimilarity is 0.8562813631228313
# Epoch 233 | Validation DotSimilarity is 0.8562239460647153
# Epoch 233 | Train Loss 0.08762150889931235
#
# Epoch 234 | Test DotSimilarity is 0.8561795076635521
# Epoch 234 | Validation DotSimilarity is 0.8567175808564161
# Epoch 234 | Train Loss 0.0876100266288713
#
# Epoch 235 | Test DotSimilarity is 0.8559761168462692
# Epoch 235 | Validation DotSimilarity is 0.856793342024957
# Epoch 235 | Train Loss 0.0875014636833707
#
# Epoch 236 | Test DotSimilarity is 0.8555076942721518
# Epoch 236 | Validation DotSimilarity is 0.8560658473004201
# Epoch 236 | Train Loss 0.08749940381994809
#
# Epoch 237 | Test DotSimilarity is 0.8554964212453254
# Epoch 237 | Validation DotSimilarity is 0.8561405101289347
# Epoch 237 | Train Loss 0.08743919555528916
#
# Epoch 238 | Test DotSimilarity is 0.8557161069580649
# Epoch 238 | Validation DotSimilarity is 0.8560540790459552
# Epoch 238 | Train Loss 0.0873915316759817
#
# Epoch 239 | Test DotSimilarity is 0.8553414402353745
# Epoch 239 | Validation DotSimilarity is 0.8561307442125206
# Epoch 239 | Train Loss 0.0873450322911046
#
# Epoch 240 | Test DotSimilarity is 0.8555318512700465
# Epoch 240 | Validation DotSimilarity is 0.8562584432063517
# Epoch 240 | Train Loss 0.08732114542320507
#
# Epoch 241 | Test DotSimilarity is 0.8553795248992239
# Epoch 241 | Validation DotSimilarity is 0.8566956388320172
# Epoch 241 | Train Loss 0.08726169496279837
#
# Epoch 242 | Test DotSimilarity is 0.855432990455888
# Epoch 242 | Validation DotSimilarity is 0.8560901689419376
# Epoch 242 | Train Loss 0.0872159317534142
#
# Epoch 243 | Test DotSimilarity is 0.855751788377823
# Epoch 243 | Validation DotSimilarity is 0.8560460615397231
# Epoch 243 | Train Loss 0.08715316845623267
#
# Epoch 244 | Test DotSimilarity is 0.8557141369288034
# Epoch 244 | Validation DotSimilarity is 0.8562471344895057
# Epoch 244 | Train Loss 0.08714038477899827
#
# Epoch 245 | Test DotSimilarity is 0.8552807976978445
# Epoch 245 | Validation DotSimilarity is 0.8556330096759757
# Epoch 245 | Train Loss 0.08706155772556609
#
# Epoch 246 | Test DotSimilarity is 0.8559091662657882
# Epoch 246 | Validation DotSimilarity is 0.8561617857360774
# Epoch 246 | Train Loss 0.08703936155308725
#
# Epoch 247 | Test DotSimilarity is 0.8555989464829247
# Epoch 247 | Validation DotSimilarity is 0.856122167911983
# Epoch 247 | Train Loss 0.0869875856389836
#
# Epoch 248 | Test DotSimilarity is 0.8558358222217892
# Epoch 248 | Validation DotSimilarity is 0.8559516665006993
# Epoch 248 | Train Loss 0.08690171917362767
#
# Epoch 249 | Test DotSimilarity is 0.8552001441009527
# Epoch 249 | Validation DotSimilarity is 0.8562369693845118
# Epoch 249 | Train Loss 0.0868788914079484
#
# Epoch 250 | Test DotSimilarity is 0.8550389915981804
# Epoch 250 | Validation DotSimilarity is 0.8560406378349651
# Epoch 250 | Train Loss 0.08686497266543616
#
# Epoch 251 | Test DotSimilarity is 0.855456543578793
# Epoch 251 | Validation DotSimilarity is 0.8563605719170951
# Epoch 251 | Train Loss 0.08683349271349454
#
# Epoch 252 | Test DotSimilarity is 0.8557979444536115
# Epoch 252 | Validation DotSimilarity is 0.8559612999434129
# Epoch 252 | Train Loss 0.08681467965847933
#
# Epoch 253 | Test DotSimilarity is 0.8557171276598426
# Epoch 253 | Validation DotSimilarity is 0.8561097351933995
# Epoch 253 | Train Loss 0.08672578498325693
#
# Epoch 254 | Test DotSimilarity is 0.8554715187882416
# Epoch 254 | Validation DotSimilarity is 0.8565279501831712
# Epoch 254 | Train Loss 0.08668941405828683
#
# Epoch 255 | Test DotSimilarity is 0.8553899869154075
# Epoch 255 | Validation DotSimilarity is 0.8561359473426808
# Epoch 255 | Train Loss 0.08669828191596704
#
# Epoch 256 | Test DotSimilarity is 0.8557366647517302
# Epoch 256 | Validation DotSimilarity is 0.8560348012460159
# Epoch 256 | Train Loss 0.08661196271261794
#
# Epoch 257 | Test DotSimilarity is 0.8556540415263837
# Epoch 257 | Validation DotSimilarity is 0.8562938507075031
# Epoch 257 | Train Loss 0.08659487227489207
#
# Epoch 258 | Test DotSimilarity is 0.8557918928209969
# Epoch 258 | Validation DotSimilarity is 0.856347815948863
# Epoch 258 | Train Loss 0.08652645228091317
#
# Epoch 259 | Test DotSimilarity is 0.8558666879985233
# Epoch 259 | Validation DotSimilarity is 0.8562953869598965
# Epoch 259 | Train Loss 0.08645736085213088
#
# Epoch 260 | Test DotSimilarity is 0.8560118232798452
# Epoch 260 | Validation DotSimilarity is 0.8561320887148013
# Epoch 260 | Train Loss 0.0864364184521058
#
# Epoch 261 | Test DotSimilarity is 0.8555446432952111
# Epoch 261 | Validation DotSimilarity is 0.8560687091424483
# Epoch 261 | Train Loss 0.08640194198305172
#
# Epoch 262 | Test DotSimilarity is 0.8555176490949907
# Epoch 262 | Validation DotSimilarity is 0.8562198698378503
# Epoch 262 | Train Loss 0.08633037574443463
#
# Epoch 263 | Test DotSimilarity is 0.8555678439880164
# Epoch 263 | Validation DotSimilarity is 0.856135979945425
# Epoch 263 | Train Loss 0.08628981427668783
#
# Epoch 264 | Test DotSimilarity is 0.855546640776008
# Epoch 264 | Validation DotSimilarity is 0.8558341913424109
# Epoch 264 | Train Loss 0.08626256143138585
#
# Epoch 265 | Test DotSimilarity is 0.8558906040483416
# Epoch 265 | Validation DotSimilarity is 0.855947814388736
# Epoch 265 | Train Loss 0.08624656842616761
#
# Epoch 266 | Test DotSimilarity is 0.8553788974943966
# Epoch 266 | Validation DotSimilarity is 0.8560971460169705
# Epoch 266 | Train Loss 0.0861903466314069
#
# Epoch 267 | Test DotSimilarity is 0.8555456095765006
# Epoch 267 | Validation DotSimilarity is 0.8557973946770627
# Epoch 267 | Train Loss 0.08619995508896101
#
# Epoch 268 | Test DotSimilarity is 0.8555438679822942
# Epoch 268 | Validation DotSimilarity is 0.8561520129594421
# Epoch 268 | Train Loss 0.0861036375426529
#
# Epoch 269 | Test DotSimilarity is 0.855181644857944
# Epoch 269 | Validation DotSimilarity is 0.8563071883592122
# Epoch 269 | Train Loss 0.08606081385077488
#
# Epoch 270 | Test DotSimilarity is 0.8552547296178385
# Epoch 270 | Validation DotSimilarity is 0.8563511229087067
# Epoch 270 | Train Loss 0.08607987625556811
#
# Epoch 271 | Test DotSimilarity is 0.8553058327678679
# Epoch 271 | Validation DotSimilarity is 0.8570687841148495
# Epoch 271 | Train Loss 0.08599512908435318
#
# Epoch 272 | Test DotSimilarity is 0.8556739883133876
# Epoch 272 | Validation DotSimilarity is 0.8560250268982198
# Epoch 272 | Train Loss 0.0859483084016831
#
# Epoch 273 | Test DotSimilarity is 0.8555674973677314
# Epoch 273 | Validation DotSimilarity is 0.8562877471994751
# Epoch 273 | Train Loss 0.08591032449242123
#
# Epoch 274 | Test DotSimilarity is 0.8558887902697349
# Epoch 274 | Validation DotSimilarity is 0.8565339900229284
# Epoch 274 | Train Loss 0.08587914311517932
#
# Epoch 275 | Test DotSimilarity is 0.8552544765844252
# Epoch 275 | Validation DotSimilarity is 0.855487495322398
# Epoch 275 | Train Loss 0.08582950533714141
#
# Epoch 276 | Test DotSimilarity is 0.8557071166724037
# Epoch 276 | Validation DotSimilarity is 0.8561447199972602
# Epoch 276 | Train Loss 0.0858308750207992
#
# Epoch 277 | Test DotSimilarity is 0.8558466510271976
# Epoch 277 | Validation DotSimilarity is 0.8561900982737598
# Epoch 277 | Train Loss 0.08578416783566188
#
# Epoch 278 | Test DotSimilarity is 0.8555370092403782
# Epoch 278 | Validation DotSimilarity is 0.8559603359784708
# Epoch 278 | Train Loss 0.08571640377677309
#
# Epoch 279 | Test DotSimilarity is 0.855154917899223
# Epoch 279 | Validation DotSimilarity is 0.8559168098427752
# Epoch 279 | Train Loss 0.08568009408899366
#
# Epoch 280 | Test DotSimilarity is 0.8557728545251816
# Epoch 280 | Validation DotSimilarity is 0.8561337530350079
# Epoch 280 | Train Loss 0.08561676414180318
#
# Epoch 281 | Test DotSimilarity is 0.8551423114010842
# Epoch 281 | Validation DotSimilarity is 0.8560395327885187
# Epoch 281 | Train Loss 0.0856016287705616
#
# Epoch 282 | Test DotSimilarity is 0.8557465052006804
# Epoch 282 | Validation DotSimilarity is 0.856504320512897
# Epoch 282 | Train Loss 0.08561510128093151
#
# Epoch 283 | Test DotSimilarity is 0.8553545992338494
# Epoch 283 | Validation DotSimilarity is 0.8564052799855266
# Epoch 283 | Train Loss 0.08556651021049172
#
# Epoch 284 | Test DotSimilarity is 0.8552275701150669
# Epoch 284 | Validation DotSimilarity is 0.855909508247373
# Epoch 284 | Train Loss 0.08548585892167067
#
# Epoch 285 | Test DotSimilarity is 0.8554527111738265
# Epoch 285 | Validation DotSimilarity is 0.8562629363473385
# Epoch 285 | Train Loss 0.08543637153674498
#
# Epoch 286 | Test DotSimilarity is 0.8551773816179964
# Epoch 286 | Validation DotSimilarity is 0.8564320205494712
# Epoch 286 | Train Loss 0.08543912066655955
#
# Epoch 287 | Test DotSimilarity is 0.8556266141484273
# Epoch 287 | Validation DotSimilarity is 0.8565592580014564
# Epoch 287 | Train Loss 0.08538385103199707
#
# Epoch 288 | Test DotSimilarity is 0.8554398213160909
# Epoch 288 | Validation DotSimilarity is 0.8560651695533865
# Epoch 288 | Train Loss 0.08537979316015396
#
# Epoch 289 | Test DotSimilarity is 0.8560151201894296
# Epoch 289 | Validation DotSimilarity is 0.8564892243599644
# Epoch 289 | Train Loss 0.08532349124840945
#
# Epoch 290 | Test DotSimilarity is 0.8554426609103255
# Epoch 290 | Validation DotSimilarity is 0.8564388513296217
# Epoch 290 | Train Loss 0.08528519256582379
#
# Epoch 291 | Test DotSimilarity is 0.8555236929087346
# Epoch 291 | Validation DotSimilarity is 0.8565111926620274
# Epoch 291 | Train Loss 0.08524426289507712
#
# Epoch 292 | Test DotSimilarity is 0.8556654829487299
# Epoch 292 | Validation DotSimilarity is 0.855721487581703
# Epoch 292 | Train Loss 0.08524641242468743
#
# Epoch 293 | Test DotSimilarity is 0.855673310551262
# Epoch 293 | Validation DotSimilarity is 0.8553846867290813
# Epoch 293 | Train Loss 0.08522357071895294
#
# Epoch 294 | Test DotSimilarity is 0.8555171889250847
# Epoch 294 | Validation DotSimilarity is 0.8561007792696309
# Epoch 294 | Train Loss 0.08514442049080814
#
# Epoch 295 | Test DotSimilarity is 0.8557018401132939
# Epoch 295 | Validation DotSimilarity is 0.8563329897278811
# Epoch 295 | Train Loss 0.08510394002484446

# %%
from google.colab import runtime
runtime.unassign()

# %% [markdown]
# # VALIDATION SAVE

# %%
# store the Subset object
# with open('/content/drive/MyDrive/NIST_SMALL/GAT_DEEP_BIG/subset.pkl', 'wb') as f:
#     pickle.dump(validation_dataset, f)

# with open("/content/drive/MyDrive/NIST_SMALL/train_subset_pow.pkl", 'wb') as handle:
#    pickle.dump(train_dataset, handle)

# with open("/content/drive/MyDrive/NIST_SMALL/validation_subset_pow.pkl", 'wb') as handle:
#    pickle.dump(validation_dataset, handle)
